# %% [markdown]
# # TM
#
# Temamodellering basert på clustring, klikk og grafanalyse.
#
# Her ser vi på
# 1. Bygg et korpus
# 1. Hvordan hente ut tematiske strukturer fra korpus
# 1. Hvordan evaluere temaer mot et større korpus
#
# Om de tematisk strukturene kommer et annetsteds fra, så kan evalueringen fremdeles benyttes, og evalueres mot bokhyllas data.

# %% [markdown]
# ### først litt kode for å komme i gang

# %%
import json
import pandas as pd
import dhlab.module_update as mu
mu.update('mods_meta')
import mods_meta as mm
import dhlab.nbtext as nb
import re
from IPython.display import Markdown, display
from collections import Counter
from dhlab.nbtokenizer import tokenize
import networkx as nx
import dhlab.graph_networkx_louvain as gnl
import datetime
from scipy.spatial.distance import cosine
from sklearn.metrics.pairwise import cosine_similarity, cosine_distances
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import json
mu.update('wordbank')
# Out:
# Updated file `C:\Users\yoons\Documents\GitHub\Trawling\mods_meta.py`
# Updated file `C:\Users\yoons\Documents\GitHub\Trawling\wordbank.py`

# %%
from wordbank import word_paradigm_many, word_lemma_many, word_form_many

# %%
mu.css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Merriweather|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Merriweather';
# 	color: DarkSlateGray;
# }
#
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# Set fontsizes for plots etc.

# %%
from nb_api_kollokasjon_konk import *
# Out:
# Updated file `C:\Users\yoons\Documents\GitHub\Trawling\mods_meta.py`
# Updated file `C:\Users\yoons\Documents\GitHub\Trawling\collocations.py`

# %%
def declensions(wordbagfamily, pos = None):
    """Set pos to subst, verb or adj for limiting the inflectional forms"""
    if isinstance(pos, list):
        res = {key: list(set([w for infl_set in word_para(wordbagfamily[key]) for w in infl_set[2] if infl_set [1] in pos])) for key in wordbagfamily}
    elif isinstance( pos, str):
        res = {key: list(set([w for infl_set in word_para(wordbagfamily[key]) for w in infl_set[2] if infl_set [1] == pos])) for key in wordbagfamily}
    else:
        res = {key: list(set([w for infl_set in word_para(wordbagfamily[key]) for w in infl_set[2]])) for key in wordbagfamily}
    return res

# %%
def word_para(ws):
    res = word_paradigm_many(ws)
    for w in ws:
        if w not in [x[0] for x in res]:
            res.append([w, 'subs', [w]])
    return res

# %% [markdown]
# # Analyse

# %% [markdown]
# ### Sammenligning
#
# Det kan være greit å ha en samling ord for utvalg av et sett ord fra korpuset. Om vi satser på en standard forskjellsanalyse, tar vi utgangspunkt i de 200 000 mest frekvente ordene i bokhylla. Tallet kan økes.

# %%
tot = nb.frame(nb.totals(200000), 'tot')

# %%
nb.normalize_corpus_dataframe(tot)
# Out:
# True

# %% [markdown]
# ### Korpus
#
# Bygg et korpus på en eller annen måte. Her ser vi på 10 bøker hentet fra en bestemt periode, markert med emneordet 'krig'.

# %%
books_ = nb.book_corpus(author = 'knaus%karl%',title='min kamp', lang= 'nob', period = (1940, 2015))

# %% [markdown]
# En kjapp oversikt over titler og forfatter.

# %%
books_
# Out:
#              urn               author     title  year
# 0  2012112638153  Knausgård, Karl Ove  Min kamp  2011
# 1  2013082806088  Knausgård, Karl Ove  Min kamp  2010
# 2  2014100308011  Knausgård, Karl Ove  Min kamp  2011
# 3  2012111508022  Knausgård, Karl Ove  Min kamp  2011
# 4  2012111508072  Knausgård, Karl Ove  Min kamp  2011
# 5  2013102906036  Knausgård, Karl Ove  Min kamp  2010
# 6  2014013105041  Knausgård, Karl Ove  Min kamp  2009
# 7  2013091306040  Knausgård, Karl Ove  Min kamp  2009

# %%
books = books_[books_.urn.isin([2014013105041, 2013102906036, 2012111508022])]

# %%
books
# Out:
#              urn               author     title  year
# 3  2012111508022  Knausgård, Karl Ove  Min kamp  2011
# 5  2013102906036  Knausgård, Karl Ove  Min kamp  2010
# 6  2014013105041  Knausgård, Karl Ove  Min kamp  2009

# %% [markdown]
# For å analysere samforekomster, telles ordene. Korpuset her tilsvarer subcorpus i Tangherlini&Leonard. Desto mindre jo bedre. Ordfrekvensene normaliseres i samme rennet.
#
# Her ser vi på trilogien Rubicon, Lass og Sangen

# %%
df = nb.frame(nb.aggregate_urns(list(books.urn)))
nb.normalize_corpus_dataframe(df)
# Out:
# True

# %%
nb.urn_concordance(urns=books.urn, word='arbeid')
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012111508022?searchText=arbeid' target='_blank' style='text-decoration:none'>Min kamp, Knausgård, Karl Ove, 2011</a>
#                 </td>
#                 <td>lagt litt sjel og mye</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>i . 6 var mer</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012111508022?searchText=arbeid' target='_blank' style='text-decoration:none'>Min kamp, Knausgård, Karl Ove, 2011</a>
#                 </td>
#                 <td>via meg ) sitt siste</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>, han prøver seg no</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013102906036?searchText=arbeid' target='_blank' style='text-decoration:none'>Min kamp, Knausgård, Karl Ove, 2010</a>
#                 </td>
#                 <td>mennesker . De skulle på</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>, jeg så det i</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013102906036?searchText=arbeid' target='_blank' style='text-decoration:none'>Min kamp, Knausgård, Karl Ove, 2010</a>
#                 </td>
#                 <td>, han hadde ikke noe</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>å passe , ingen tider</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013102906036?searchText=arbeid' target='_blank' style='text-decoration:none'>Min kamp, Knausgård, Karl Ove, 2010</a>
#                 </td>
#                 <td>skulle vi levere et større</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>før vi sluttet , og</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013102906036?searchText=arbeid' target='_blank' style='text-decoration:none'>Min kamp, Knausgård, Karl Ove, 2010</a>
#                 </td>
#                 <td>, mens hun var på</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>. Så spiste vi middag</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013102906036?searchText=arbeid' target='_blank' style='text-decoration:none'>Min kamp, Knausgård, Karl Ove, 2010</a>
#                 </td>
#                 <td>hadde jeg ikke levert noe</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>til ham , som de</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014013105041?searchText=arbeid' target='_blank' style='text-decoration:none'>Min kamp, Knausgård, Karl Ove, 2009</a>
#                 </td>
#                 <td>enn disse arbeiderne , intet</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>virket mer meningsfullt enn deres</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014013105041?searchText=arbeid' target='_blank' style='text-decoration:none'>Min kamp, Knausgård, Karl Ove, 2009</a>
#                 </td>
#                 <td>ikke pappa skulle gjøre noe</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>før første time begynte ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014013105041?searchText=arbeid' target='_blank' style='text-decoration:none'>Min kamp, Knausgård, Karl Ove, 2009</a>
#                 </td>
#                 <td>Og alt de gjorde av</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>, gjorde vi også ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014013105041?searchText=arbeid' target='_blank' style='text-decoration:none'>Min kamp, Knausgård, Karl Ove, 2009</a>
#                 </td>
#                 <td>, imidlertid ikke i sitt</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>på skolen og i politikken</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014013105041?searchText=arbeid' target='_blank' style='text-decoration:none'>Min kamp, Knausgård, Karl Ove, 2009</a>
#                 </td>
#                 <td>. Det var et tungt</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>, men nokså gøy ;</td>
#             </tr>
# </table>

# %% [markdown]
# Når ordene sammenlignes med det som er forventet dukker det opp en slags tematisk struktur, som vi ser i neste output. Ordene er toppordene for de som utgjør en forskjell på korpuset sammenlignet med resten av bokhylla. Men merk at enkelte bøker kan dominere her, så derfor lurt å minske antallet, eller analysere bøkene en for en.
#
# Vi bruker korpus-ordene for å lage en tematisk struktur. Alt vi vet foreløpig er at hver og en av dem forekommer hyppigere i korpuset enn ellers i bokverdenen. Hvordan henger de sammen?

# %%
selection_ = word_form_many(list(nb.frame_sort(nb.frame(df[0]/tot.tot)).head(700).index))
selection = [x[0] for x in selection_ if 'subs' in x[1] or 'verb' in x[1]]

# %%
selection
# Out:
# ['studielånet',
#  'godtet',
#  'godtet',
#  'godtet',
#  'nachspiel',
#  'nachspiel',
#  'støvlettene',
#  'morfar',
#  'lesesalen',
#  'byggefelt',
#  'byggefelt',
#  'framsiden',
#  'grudd',
#  'pisset',
#  'pisset',
#  'pisset',
#  'diskoteket',
#  'stemningene',
#  'stemningene',
#  'hybelen',
#  'stereoanlegget',
#  'singelen',
#  'gaula',
#  'gaula',
#  'gaula',
#  'sjans',
#  'farmor',
#  'farmor',
#  'løvtrærne',
#  'klasseforstanderen',
#  'klasseforstanderen',
#  'klasseforstanderen',
#  'samfunnshuset',
#  'ølen',
#  'bandene',
#  'bandene',
#  'hundrelapp',
#  'trettenåring',
#  'kuken',
#  'kassettene',
#  'debutere',
#  'haike',
#  'knulla',
#  'knulla',
#  'knulla',
#  'ett-tiden',
#  'dreit',
#  'kaffetrakteren',
#  'kaffetrakteren',
#  'kaffetrakteren',
#  'jakkene',
#  'jakkene',
#  'klasseforstander',
#  'klasseforstander',
#  'klasseforstander',
#  'baderommet',
#  'hettene',
#  'hettene',
#  'låtene',
#  'skyvedøren',
#  'underbuksen',
#  'snøballer',
#  'åpneren',
#  'åpneren',
#  'åpneren',
#  'vedrørte',
#  'servitørene',
#  'bokanmeldelser',
#  'gnikket',
#  'gnikket',
#  'gnikket',
#  'gnikket',
#  'kaféene',
#  'flyttelasset',
#  'utstrålingen',
#  'platespilleren',
#  'platespilleren',
#  'platespilleren',
#  'underbuksene',
#  'underbuksene',
#  'haiket',
#  'haiket',
#  'boblen',
#  'ranselen',
#  'hovedfaget',
#  'vindusviskerne',
#  'vindusviskerne',
#  'vindusviskerne',
#  'akademiet',
#  'debutert',
#  'tevann',
#  'tevann',
#  'genserne',
#  'genserne',
#  'genserne',
#  'ferjen',
#  'takrennene',
#  'takrennene',
#  'grantrærne',
#  'svømmehallen',
#  'røykte',
#  'fritidsklubben',
#  'litteraturvitenskap',
#  'bagasjebrettet',
#  'labbet',
#  'labbet',
#  'klinte',
#  'klinte',
#  'lighteren',
#  'lighteren',
#  'lighteren',
#  'coveret',
#  'handkleet',
#  'vagge',
#  'vagge',
#  'vagge',
#  'pratet',
#  'pratet',
#  'pratet',
#  'sjekte',
#  'sjekte',
#  'sjekte',
#  'dressjakke',
#  'dressjakke',
#  'attenhundretallet',
#  'manuset',
#  'slegga',
#  'slegga',
#  'slegga',
#  'grusveien',
#  'mopeder',
#  'kuk',
#  'luntet',
#  'luntet',
#  'luntet',
#  'farfar',
#  'forvernet',
#  'bassist',
#  'pappa',
#  'pappa',
#  'pappa',
#  'taxien',
#  'cornflakes',
#  'skumret',
#  'skumret',
#  'ringeklokken',
#  'smekken',
#  'vokalisten',
#  'svabergene',
#  'nøkkelknippet',
#  'scones',
#  'scones',
#  'gategutt',
#  'yret',
#  'yret',
#  'yret',
#  'pc-en',
#  'kassettspilleren',
#  'kassettspilleren',
#  'kassettspilleren',
#  'pikken',
#  'pikken',
#  'ytterklærne',
#  'gulost',
#  'telefonkiosken',
#  'grine',
#  'refusert',
#  'fise',
#  'oppkjørselen',
#  'femtilapp',
#  'sokken',
#  'rykning',
#  'rykning',
#  'kvelt',
#  'prosaen',
#  'lillebroren',
#  'knaggene',
#  'kaféer',
#  'bakkene',
#  'friminuttet',
#  'diskoteker',
#  'vindfanget',
#  'dusjet',
#  'dusjet',
#  'gardinen',
#  'trehusene',
#  'syklene',
#  'kateteret',
#  'deodorant',
#  'knatt',
#  'knatt',
#  'knatt',
#  'rundstykkene',
#  'skrivemaskinen',
#  'shortsen',
#  'ekspeditøren',
#  'romjula',
#  'trommeslager',
#  'trommeslager',
#  'trommeslager',
#  'tuster',
#  'tuster',
#  'tuster',
#  'bassisten',
#  'buksert',
#  'utslagsvasken',
#  'mormor',
#  'mormor',
#  'tv-en',
#  'asfalten',
#  'slurken',
#  'dressjakken',
#  'seilskuter',
#  'seilskuter',
#  'seilskuter',
#  'støvletter',
#  'bladd',
#  'søpla',
#  'søpla',
#  'søpla',
#  'søpla',
#  'kantinen',
#  'brunost',
#  'parodien',
#  'kartongene',
#  'knakte',
#  'låten',
#  'badstua',
#  'toalettpapir',
#  'toalettpapir',
#  'friminuttene',
#  'syklet',
#  'syklet',
#  'småløp',
#  'småløp',
#  'kakket',
#  'kakket',
#  'kakket',
#  'dongeribukser',
#  'dongeribukser',
#  'heksekunst',
#  'drite',
#  'sakket',
#  'sakket',
#  'gymnaset',
#  'baconet',
#  'karbonader',
#  'kaskade',
#  'haspen',
#  'anmeldelsene',
#  'reolen',
#  'framstod',
#  'postkassene',
#  'postkassene',
#  'kubben',
#  'glidelåsen',
#  'menighetshuset',
#  'unatur',
#  'trommeslageren',
#  'trommeslageren',
#  'trommeslageren',
#  'husarrest',
#  'skrante',
#  'skytebanen',
#  'skrudde',
#  'skrudde',
#  'mamma',
#  'campingvognen',
#  'keeperen',
#  'keeperen',
#  'keeperen',
#  'plastposen',
#  'bærepose',
#  'dassen',
#  'måndagen',
#  'bussen',
#  'taxi',
#  'bordtennis',
#  'meterne',
#  'underbukse',
#  'underbukse',
#  'labbe',
#  'raketten',
#  'singler',
#  'singler',
#  'singler',
#  'singler',
#  'joggeskoene',
#  'ringlet',
#  'ringlet',
#  'ringlet',
#  'ringlet',
#  'ringlet',
#  'stumpet',
#  'stumpet',
#  'kassetter',
#  'friminutt',
#  'friminutt',
#  'vortene',
#  'vortene',
#  'torsker',
#  'porselenet',
#  'besinnet',
#  'besinnet',
#  'skylte',
#  'supermarkedet',
#  'gummistøvler',
#  'sekstenåring',
#  'sildret',
#  'sildret',
#  'sildret',
#  'familieselskap',
#  'familieselskap',
#  'dongeribukse',
#  'dongeribukse',
#  'røykt',
#  'dyreparken',
#  'tolvårsalderen',
#  'tolvårsalderen',
#  'tolvårsalderen',
#  'underkroppen',
#  'vafler',
#  'vafler',
#  'kragebenet',
#  'rumper',
#  'rumper',
#  'rumper',
#  'skydekket',
#  'plopp',
#  'plopp',
#  'sjenansen',
#  'skjeggstubber',
#  'meske',
#  'baklommen',
#  'hoggestabben',
#  'heldet',
#  'heldet',
#  'melkekartong',
#  'påhengsmotoren',
#  'verdenen',
#  'stryket',
#  'virvelen',
#  'sivilarbeidere',
#  'refusjonen',
#  'resepsjonist',
#  'forsont',
#  'fartsgrensene',
#  'fartsgrensene',
#  'vaskekjelleren',
#  'vaskekjelleren',
#  'vaskekjelleren',
#  'plastpose',
#  'haket',
#  'haket',
#  'semesteret',
#  'suset',
#  'posene',
#  'førtiårene',
#  'korka',
#  'korka',
#  'ølflasker',
#  'ølflasker',
#  'gjennomtrengt',
#  'ferieturen',
#  'skapdøren',
#  'lommelyktene',
#  'lommelyktene',
#  'romjulen',
#  'pekefingrene',
#  'sankthansaften',
#  'praiet',
#  'praiet',
#  'praiet',
#  'plattingen',
#  'stigene',
#  'pennalet',
#  'mislykkethet',
#  'mislykkethet',
#  'asfalterte',
#  'bunken',
#  'vestlending',
#  'snoket',
#  'snoket',
#  'handbrekket',
#  'kippet',
#  'kippet',
#  'kippet',
#  'tolererte',
#  'underarmene',
#  'klampet',
#  'klampet',
#  'gitaren',
#  'kveldsmat',
#  'hoggorm',
#  'fyrstikkesken',
#  'idrettshallen',
#  'utspilte',
#  'oversvømmelsen',
#  'skyflet',
#  'skyflet',
#  'flaggstangen',
#  'askebegeret',
#  'vendingene',
#  'vendingene',
#  'fredagen',
#  'inhalere',
#  'tila',
#  'livene',
#  'skoleelevene',
#  'gitaristen',
#  'kranglene',
#  'kranglene',
#  'furuene',
#  'furuene',
#  'klasserommene',
#  'kline',
#  'kline',
#  'verdenene',
#  'skimret',
#  'skimret',
#  'treningsdrakt',
#  'treningsdrakt',
#  'bergenser',
#  'bergenser',
#  'bergenser',
#  'løpeild',
#  'kødder',
#  'kødder',
#  'smalnet',
#  'smalnet',
#  'askebegre',
#  'kiosken',
#  'smokingen',
#  'boligfeltet',
#  'scenarioet',
#  'bæreposer',
#  'rundstykket',
#  'lobotomi',
#  'halvtime',
#  'trettiårene',
#  'pisse',
#  'haik',
#  'haik',
#  'mellomfag',
#  'mellomfag',
#  'barnålene',
#  'barnålene',
#  'gjennomstrømmet',
#  'gjennomstrømmet',
#  'jernene',
#  'knaggen',
#  'vekslepengene',
#  'presangene',
#  'spadene',
#  'paraplyer',
#  'publikummet',
#  'klunk',
#  'klunk',
#  'klunk',
#  'klunk',
#  'espresso',
#  'skjerfet',
#  'vodkaen',
#  'perforerte',
#  'vokalist',
#  'studiekamerater',
#  'spedde',
#  'kritikker',
#  'kilometeren',
#  'bakgårder',
#  'frisørsalong',
#  'jakker',
#  'jakker',
#  'juleferie',
#  'bikini',
#  'kleiva',
#  'vinterferien',
#  'platting',
#  'skulket',
#  'skulket',
#  'skulket',
#  'fornemmet',
#  'fornemmet',
#  'eiken',
#  'eiken',
#  'romstere',
#  'sprettert',
#  'sportsforretning',
#  'sportsforretning',
#  'joggesko',
#  'joggesko',
#  'kubbe',
#  'kubbe',
#  'niggere',
#  'kaffekjelen',
#  'vaktrommet',
#  'termosen',
#  'handkle',
#  'notisbøker',
#  'notisbøker',
#  'attenåring',
#  'merkverdigheter',
#  'merkverdigheter',
#  'svømmeføtter']

# %% [markdown]
# Ordene over kan vi bruke til å konstruere en graf basert på samforekomster. Kommandoen `nb.make_network_graph` tar en liste med ord og strukturer dem basert på samforekomst. Et ord W er koblet med en bue til et annet ord V, hvis W og V opptrer i samme avsnitt. Det gir en grafstruktur som kan visualiseres og analyseres.
#
# Her ser vi bare på ord som er mer eller mindre unike for tekstene i korpuset. Antallet ord bestemmes av parametret for `head()` i koden under. Her er den satt til 300, andre verdier gir flere ord, som vil øke størrels og antall på temaer.
#
# Ordene som skal brukes kunne i prinsippert vært hele korpuset, men for å komme i havn før nyttårsaften, og ikke sprenge datakapasiteten gjøres et utvalg. Forskjellig sett ord kan velges og gi andre resultat.

# %%
Gs = [nb.make_network_graph(str(u), selection) for u in books.urn]

# %%
G = nx.Graph()
for g in Gs:
    G.add_edges_from(g.edges(data=True))

# %% [markdown]
# Grafen ser sånn ut. Med fargelagte noder for clustertilhørighet.

# %%
gnl.show_graph(G)

# %% [markdown]
# Nedenfor kan vi se på clustrene generert fra grafen (Louvain-metoden), som til syvende og sist er antatt å definere et aspekt ved den tematiske strukturen for korpuset. Tematikken er her basert på de viktigste ordene, beskrevet ovenfor. Andre detaljer vil komme frem ved å bruke andre ord som input, ordsekker laget ved kollokasjon for eksempel.
#
# En mulig svakhet ved clustringsalgoritmer er at de partisjonerer ordene, sånn at ord ikke forekommer i to eller fler clustre, til forskjell fra mixtur-modeller som LDA og NMF. Klikkstrukturene er bedre i så henseende. Vi bruker dem ikke nå i første omgang men se artikkelen om forskjellen på klikk og clustring ["Graph Analysis of Word Networks”](http://ceur-ws.org/Vol-2021/paper6.pdf)..
#
# Merkelappen på clustrene er hentet fra de mest sentrale ordene i clustret. Og hjelper litt med en begrepsmessig orden.

# %%
gnl.show_communities(G)
# Out:
# bussen-bakkene :  bussen, bakkene, oppkjørselen, støvlettene, småløp, handkle, sildret, grusveien, kveldsmat, askebegeret, supermarkedet, skjerfet, friminuttet, knaggen, byggefelt, underbuksen, underbukse, snøballer, skydekket, kilometeren, kakket, plastposen, sakket, sokken, labbe, gnikket, bordtennis, knulla, ytterklærne, anmeldelsene
#
# pratet-skrudde :  pratet, skrudde, halvtime, taxi, gymnaset, livene, fredagen, trettiårene, kantinen, pc-en, taxien, nachspiel, stumpet, litteraturvitenskap, lesesalen, husarrest, takrennene, diskoteker, hovedfaget, kritikker, samfunnshuset, utstrålingen, fritidsklubben, ringeklokken, stemningene, ringlet, vagge, ett-tiden, ølen, askebegre, knakte, åpneren, skulket, tevann, kaféer, plopp, sjekte, platting, gategutt, kippet, barnålene, bergenser, debutere, merkverdigheter, bokanmeldelser, tolererte, forsont, scenarioet, karbonader, femtilapp, debutert
#
# røykte-asfalten :  røykte, asfalten, syklet, verdenen, tv-en, klinte, haiket, nøkkelknippet, joggesko, kline, utspilte, skyvedøren, røykt, bladd, besinnet, telefonkiosken, diskoteket, mopeder, dressjakke, campingvognen, boligfeltet, hettene, menighetshuset, bakgårder, syklene, bagasjebrettet, vodkaen, handbrekket, idrettshallen, haik, oversvømmelsen, stryket, snoket, genserne, underkroppen, resepsjonist
#
# hybelen-plastpose :  hybelen, plastpose, kiosken, akademiet, dusjet, meterne, posene, sjans, luntet, gardinen, fornemmet, svømmehallen, søpla, grantrærne, paraplyer, manuset, godtet, postkassene, prosaen, dressjakken, tuster, skimret, løvtrærne, refusert, haket, refusjonen, lighteren, badstua, gjennomstrømmet, rumper, yret, sjenansen, bæreposer, skyflet, vestlending, slurken, torsker, keeperen, plattingen, buksert, furuene, kaféene, skrante, kvelt
#
# mamma-pappa :  mamma, pappa, morfar, farmor, farfar, mormor, ranselen, gummistøvler, studielånet, labbet, gulost, svabergene, boblen, ekspeditøren, semesteret, lillebroren, kaskade, haike, framsiden, grine, vedrørte, ølflasker, knatt, kaffekjelen, underarmene, friminutt, flyttelasset, pennalet, perforerte, rundstykket, trehusene, kranglene, seilskuter, sekstenåring, attenhundretallet, vaskekjelleren, klampet, bikini, trettenåring, ferjen, dyreparken, vindusviskerne, sankthansaften, bærepose, grudd, skapdøren, sportsforretning, sprettert, cornflakes, baklommen, skytebanen, shortsen, treningsdrakt, svømmeføtter, meske, inhalere, slegga, kubben, familieselskap, kragebenet, romjula, verdenene, presangene, niggere, notisbøker, påhengsmotoren, smalnet, fartsgrensene, termosen, romstere, kleiva, rundstykkene, unatur
#
# skylte-baderommet :  skylte, baderommet, pisset, suset, glidelåsen, kaffetrakteren, dreit, underbuksene, førtiårene, pikken, pisse, smekken, gjennomtrengt, toalettpapir, asfalterte, praiet, kartongene, hundrelapp, vaktrommet, rykning, kuken, tolvårsalderen, melkekartong, kuk, servitørene, vekslepengene, dassen, utslagsvasken
#
# singelen-skrivemaskinen :  singelen, skrivemaskinen, stereoanlegget, gitaren, låten, låtene, framstod, bunken, bandene, raketten, kassettene, kassettspilleren, dongeribukser, trommeslager, gitaristen, kateteret, coveret, bassist, måndagen, vokalist, platespilleren, klasseforstanderen, trommeslageren, smokingen, attenåring, klasseforstander, kassetter, singler, lommelyktene, skjeggstubber, bassisten, vendingene
#
# handkleet-friminuttene :  handkleet, friminuttene, jakker, jakkene, knaggene, joggeskoene, porselenet, klasserommene, støvletter, skumret, heldet, espresso, klunk
#
# vafler-brunost :  vafler, brunost, scones, tila
#
# sivilarbeidere-juleferie :  sivilarbeidere, juleferie, romjulen
#
# vortene-baconet :  vortene, baconet
#
# ferieturen-flaggstangen :  ferieturen, flaggstangen
#
# hoggestabben-kubbe :  hoggestabben, kubbe

# %% [markdown]
# ### Evaluering, tråling
#
# Temaene generert over kan analyseres på selve korpuset, eller på et annet større korpus. Først ser vi på selve korpust

# %% [markdown]
# Temaene hentes ut som en familie ordklasser

# %%
themes = gnl.community_dict(G)

# %% [markdown]
# For å få med bøyningsvarianter, legger vi til infleksjonsformer for ord som har det.

# %%
themes_plus = declensions(themes)

# %% [markdown]
# ### Gå gjennom bøker og tell opp temaene

# %%
evals = nb.wordbag_eval(themes_plus, list(books_.urn)).astype(int)

# %%
evals.style.background_gradient(axis = 0)
# Out:
# <style  type="text/css" >
#     #T_e85aed2e_296d_11eb_a528_985fd3509bc7row0_col0 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row0_col1 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row0_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row0_col8 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row0_col9 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row0_col10 {
#             background-color:  #046299;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row0_col11 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row0_col12 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row0_col13 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row1_col0 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row1_col2 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row1_col3 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row1_col4 {
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row1_col5 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row1_col6 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row1_col7 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row1_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row1_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row1_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row1_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row1_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row1_col13 {
#             background-color:  #b0c2de;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row2_col0 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row2_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row2_col2 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row2_col3 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row2_col4 {
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row2_col5 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row2_col6 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row2_col7 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row2_col8 {
#             background-color:  #034369;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row2_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row2_col10 {
#             background-color:  #023c5f;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row2_col11 {
#             background-color:  #0569a4;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row2_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row2_col13 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row3_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row3_col2 {
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row3_col4 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row3_col5 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row3_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row3_col7 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row3_col8 {
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row3_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row3_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row3_col11 {
#             background-color:  #4c99c5;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row3_col12 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row3_col13 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row4_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row4_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row4_col2 {
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }    #T_e85aed2e_296d_11eb_a528_985fd3509bc7row4_col3 {
#             background-color:  #023858;
#             colo

# %% [markdown]
# ### Evaluere mot et skjønnlitterært korpus fra samme era.
#
# Evalueringen er uavhengig av hvordan temaordene er laget. De kan lages for hånd, genereres med LDA, eller som over, hentet fra grafer. Evalueringen teller opp ordsekkfamilien over et sett ord.

# %%
testkorpus = nb.book_corpus(ddk = '839%', period = (1990, 2010), limit = 20)

# %%
testeval = nb.wordbag_eval(themes_plus, list(testkorpus.urn)).astype(int)

# %% [markdown]
# Korpuset er litt for stort til visualisering, så sorterer på et trekk og tar ut de 50 beste

# %%
testeval.sort_values(by = 'snitt', ascending = False).head(50).style.background_gradient(axis = 0)
# Out:
# <style  type="text/css" >
#     #T_ea393688_296d_11eb_a083_985fd3509bc7row0_col0 {
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row0_col2 {
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row0_col3 {
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row0_col4 {
#             background-color:  #04649e;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row0_col5 {
#             background-color:  #0569a4;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row0_col7 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row0_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row0_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row0_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row0_col11 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row0_col12 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row0_col13 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row1_col1 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row1_col2 {
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row1_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row1_col5 {
#             background-color:  #197db7;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row1_col6 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row1_col7 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row1_col8 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row1_col9 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row1_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row1_col11 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row1_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row1_col13 {
#             background-color:  #046198;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row2_col0 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row2_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row2_col2 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row2_col3 {
#             background-color:  #4a98c5;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row2_col4 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row2_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row2_col6 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row2_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row2_col8 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row2_col9 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row2_col10 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row2_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row2_col12 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row2_col13 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row3_col0 {
#             background-color:  #167bb6;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row3_col1 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row3_col2 {
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row3_col3 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row3_col4 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row3_col5 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row3_col6 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row3_col7 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row3_col8 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row3_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row3_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row3_col11 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row3_col12 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row3_col13 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row4_col0 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row4_col2 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_ea393688_296d_11eb_a083_985fd3509bc7row4_col3 {
#             background-color:  #167bb6;
#             colo

# %%
mdata = [nb.metadata(u) for u in testeval.sort_values(by = 'snitt', ascending = False).head(50).index]

# %%
nb.frame(mdata)
# Out:
#                                                     0
# 0   [2008010801045, Michelet, Jon, 1993, Mannen på...
# 1   [2007110104005, Lie, Jonas, 1991, Familien på ...
# 2   [2012082908076, Bakken, Thorbjørn, 2005, Vidar...
# 3   [2013012205074, Gunnerud, Jørgen, 2009, Byen m...
# 4   [2008020500015, Rypdal, Arild, 1994, Orakel, ,...
# 5   [2014070406025, , 2002, Sine særegne evners tr...
# 6   [2009030200050, Jansson, Tove, 2002, Det usynl...
# 7   [2009020304082, Risa, Einar O., 1997, Velvære,...
# 8   [2008081204031, Hauge, Olav H., 1996, Dikt i s...
# 9   [2011102406008, Sjón, 2005, Skugga-Baldur, et ...
# 10  [2008022200099, Birkedal, Arnt, 1995, Øya bort...
# 11  [2011032108107, , 2005, 55 dikt om far, antolo...
# 12  [2014102108084, Svingen, Arne, 2001, Huberts v...
# 13  [2007121000057, , 1993, Alexandrias aske, , Ca...
# 14  [2011031005045, Kaldhol, Marit, 2000, Likevel,...

# %% [markdown]
# Tema som komplekse tegn. Hva er det som gir treff fra et tema/cluster i nye bøker?

# %%
def check_urn(urn, themes):
    return {x:nb.word_freq(urn, themes[x]) for x in themes}

# %%
check_urn(2008010801045, themes_plus)
# Out:
# {'bussen-bakkene': {'askebegre': 1,
#   'bakker': 1,
#   'bussen': 1,
#   'bussene': 1,
#   'busser': 1,
#   'grusvei': 1,
#   'knagg': 1,
#   'knulla': 1,
#   'knulle': 1,
#   'oppkjørselen': 1,
#   'plastposen': 1,
#   'sildrer': 1,
#   'skjerf': 1,
#   'skydekke': 1,
#   'skydekket': 1,
#   'snøballer': 1,
#   'støvletter': 1,
#   'askebeger': 2,
#   'bakke': 2,
#   'grusveiene': 2,
#   'knaggen': 2,
#   'knuller': 2,
#   'plastposer': 2,
#   'snøball': 2,
#   'buss': 3,
#   'plastpose': 3,
#   'askebegeret': 4,
#   'knull': 4,
#   'bakken': 6,
#   'kilometer': 7},
#  'pratet-skrudde': {'askebegre': 1,
#   'diskotek': 1,
#   'forsonende': 1,
#   'kantine': 1,
#   'karbonade': 1,
#   'prat': 1,
#   'prate': 1,
#   'stemning': 1,
#   'stump': 1,
#   'stumper': 1,
#   'taxien': 1,
#   'askebeger': 2,
#   'kantina': 2,
#   'skrudd': 2,
#   'skulker': 2,
#   'skrue': 3,
#   'askebegeret': 4,
#   'fredag': 4,
#   'skru': 4,
#   'skrudde': 4,
#   'skrur': 4,
#   'halvtime': 5,
#   'taxi': 6,
#   'øl': 6,
#   'kafé': 7,
#   'kafeen': 8,
#   'åpner': 17,
#   'liv': 34,
#   'livet': 36},
#  'røykte-asfalten': {'bagasjebrettet': 1,
#   'bakgård': 1,
#   'bakgårdene': 1,
#   'diskotek': 1,
#   'dressjakka': 1,
#   'handbrekket': 1,
#   'hetta': 1,
#   'kliner': 1,
#   'oversvømmelse': 1,
#   'røykt': 1,
#   'stryk': 1,
#   'syklet': 1,
#   'telefonkiosken': 1,
#   'telefonkioskene': 1,
#   'verdener': 1,
#   'bla': 2,
#   'bladde': 2,
#   'genser': 2,
#   'genseren': 2,
#   'klin': 2,
#   'nøkkelknippe': 2,
#   'syklene': 2,
#   'vodka': 2,
#   'klint': 3,
#   'røykte': 3,
#   'telefonkiosk': 3,
#   'stryker': 4,
#   'sykler': 8,
#   'røyke': 9,
#   'sykkel': 9,
#   'bakgården': 10,
#   'blar': 10,
#   'røyker': 11,
#   'røyk': 30,
#   'sykkelen': 43,
#   'verden': 58},
#  'hybelen-plastpose': {'badstua': 1,
#   'dressjakka': 1,
#   'dusj': 1,
#   'gardinet': 1,
#   'hake': 1,
#   'hybelen': 1,
#   'kvalte': 1,
#   'lightere': 1,
#   'lunta': 1,
#   'paraplyene': 1,
#   'plastposen': 1,
#   'poser': 1,
#   'prosa': 1,
#   'søppel': 1,
#   'furua': 2,
#   'gardinene': 2,
#   'gardiner': 2,
#   'grantrær': 2,
#   'lighter': 2,
#   'lighteren': 2,
#   'plastposer': 2,
#   'posene': 2,
#   'rumpe': 2,
#   'søpla': 2,
#   'godta': 3,
#   'kvalt': 3,
#   'kvele': 3,
#   'plastpose': 3,
#   'kiosk': 4,
#   'kiosken': 4,
#   'paraply': 4,
#   'posen': 4,
#   'postkassa': 4,
#   'sjanse': 4,
#   'slurk': 4,
#   'furu': 5,
#   'haka': 5,
#   'kafé': 7,
#   'slurker': 7,
#   'bukser': 8,
#   'kafeen': 8,
#   'meter': 17,
#   'godt': 71},
#  'mamma-pappa': {'attenhundretall': 1,
#   'baklomma': 1,
#   'bikini': 1,
#   'bobla': 1,
#   'ekspeditør': 1,
#   'ferje': 1,
#   'flyttelasset': 1,
#   'knatter': 1,
#   'kubbe': 1,
#   'kubben': 1,
#   'lillebroren': 1,
#   'notisbok': 1,
#   'notisboka': 1,
#   'romjula': 1,
#   'romsterer': 1,
#   'rundstykker': 1,
#   'skytebane': 1,
#   'skytebanen': 1,
#   'skytebaner': 1,
#   'termosen': 1,
#   'trehusene': 1,
#   'trehuset': 1,
#   'trettenåring': 1,
#   'underarm': 1,
#   'underarmen': 1,
#   'verdener': 1,
#   'vindusviskerne': 1,
#   'cornflakes': 2,
#   'ekspeditøren': 2,
#   'flyttelass': 2,
#   'grein': 2,
#   'gru': 2,
#   'gulost': 2,
#   'papp': 2,
#   'svaberget': 2,
#   'termos': 2,
#   'trehus': 2,
#   'krangel': 3,
#   'svaberg': 3,
#   'grine': 4,
#   'griner': 5,
#   'mamma': 6,
#   'pappa': 6,
#   'verden': 58},
#  'skylte-baderommet': {'asfaltert': 1,
#   'drite': 1,
#   'førtiåra': 1,
#   'hundrelapper': 1,
#   'pissa': 1,
#   'pist': 1,
#   'servitøren': 1,
#   'skylle': 1,
#   'smekker': 1,
#   'smekket': 1,
#   'dassen': 2,
#   'piss': 2,
#   'pisset': 2,
#   'smekk': 2,
#   'pisser': 3,
#   'sus': 3,
#   'driter': 4,
#   'pisse': 5,
#   'dass': 7,
#   'dritt': 8,
#   'pikken': 8},
#  'singelen-skrivemaskinen': {'band': 1,
#   'bande': 1,
#   'bunker': 1,
#   'cover': 1,
#   'framsto': 1,
#   'kassetter': 1,
#   'kassettspilleren': 1,
#   'låt': 1,
#   'raketter': 1,
#   'stereoanlegg': 1,
#   'vending': 1,
#   'vendingen': 1,
#   'attenåring': 2,
#   'lommelykt': 2,
#   'låter': 2,
#   'rakett': 2,
#   'singel': 2,
#   'vendinger': 2,
#   'bunken': 3,
#   'singler': 3,
#   'skrivemaskinen': 3,
#   'bunke': 4,
#   'banden': 5,
#   'skrivemaskin': 5},
#  'handkleet-friminuttene': {'jakkene': 1,
#   'klasserom': 1,
#   'knagg': 1,
#   'støvletter': 1,
#   'jakke': 2,
#   'knaggen': 2,
#   'porselen': 2,
#   'espresso': 3,
#   'jakka': 3},
#  'vafler-brunost': {'brunost': 1, 'vafler': 1},
#  'sivilarbeidere-juleferie': {'romjula': 1},
#  'vortene-baconet': {'bacon': 2},
#  'ferieturen-flaggstangen': {},
#  'hoggestabben-kubbe': {'kubbe': 1, 'kubben': 1}}

# %%
values = [x for y in themes_plus.values() for x in y]

# %%
GL = nb.make_network_graph(2008010801045, values)

# %%
gnl.show_graph(GL)

# %%
gnl.show_communities(GL)
# Out:
# jakka-plastpose :  jakka, plastpose, plastposen, asfaltert, underarm
#
# dritt-askebegeret :  dritt, askebegeret, bunke, skulker, lighteren, kassetter, trehus
#
# livet-skrivemaskinen :  livet, skrivemaskinen, søpla, knull, gardinene, vodka, attenåring
#
# plastposer-mamma :  plastposer, mamma, pappa, bacon
#
# sykkelen-meter :  sykkelen, meter, kilometer, sykler, bakgården, sykkel, åpner, svaberget, skrudde, godta, furu, busser, flyttelass, baklomma, fredag, syklene, gardiner, sjanse, bagasjebrettet, klint, kantina, knatter, papp
#
# stumper-røykte :  stumper, røykte, banden
#
# blar-lighter :  blar, lighter, pisset, bla, knulle, bunken
#
# godt-verden :  godt, verden, røyker, røyk, liv, skrivemaskin, smekket, posen, oversvømmelse, gulost, sildrer, røykt, knuller, trehusene, kvele, genser, låter, postkassa, driter, kvalt, bladde, kantine, skytebanen, posene
#
# kiosken-brunost :  kiosken, brunost, rundstykker, kiosk
#
# bukser-jakke :  bukser, jakke
#
# bunker-hundrelapper :  bunker, hundrelapper
#
# buss-bussen :  buss, bussen
#
# paraplyene-cornflakes :  paraplyene, cornflakes
#
# pissa-cover :  pissa, cover
#
# pisse-kafé :  pisse, kafé, dassen, pikken, øl, pisser, kafeen, slurker, skjerf, hybelen, skrur, dass, svaberg
#
# støvletter-espresso :  støvletter, espresso
#
# grine-griner :  grine, griner
#
# røyke-termos :  røyke, termos, skru, grusveiene
#
# skrudd-haka :  skrudd, haka
#
# hake-kubben :  hake, kubben
#
# karbonade-notisbok :  karbonade, notisbok
#
# klasserom-snøballer :  klasserom, snøballer
#
# vending-krangel :  vending, krangel
#
# lunta-søppel :  lunta, søppel
#
# låt-romsterer :  låt, romsterer
#
# oppkjørselen-singel :  oppkjørselen, singel
#
# stryker-skylle :  stryker, skylle, porselen
#
# smekk-rakett :  smekk, rakett
#
# snøball-telefonkiosk :  snøball, telefonkiosk
