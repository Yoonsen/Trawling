# %% [markdown]
# # TM
#
# Temamodellering basert på clustring, klikk og grafanalyse.
#
# Her ser vi på
# 1. Bygg et korpus
# 1. Hvordan hente ut tematiske strukturer fra korpus
# 1. Hvordan evaluere temaer mot et større korpus
#
# Om de tematisk strukturene kommer et annetsteds fra, så kan evalueringen fremdeles benyttes, og evalueres mot bokhyllas data.

# %% [markdown]
# ### først litt kode for å komme i gang

# %%
import json
import pandas as pd
import dhlab.module_update as mu
mu.update('mods_meta')
import mods_meta as mm
import dhlab.nbtext as nb
import re
from IPython.display import Markdown, display
from collections import Counter
from dhlab.nbtokenizer import tokenize
import networkx as nx
import dhlab.graph_networkx_louvain as gnl
import datetime
from scipy.spatial.distance import cosine
from sklearn.metrics.pairwise import cosine_similarity, cosine_distances
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import json
mu.update('wordbank')
# Out:
# Updated file `C:\Users\yoons\Documents\GitHub\Trawling\mods_meta.py`
# Updated file `C:\Users\yoons\Documents\GitHub\Trawling\wordbank.py`

# %%
from wordbank import word_paradigm_many, word_lemma_many, word_form_many

# %%
mu.css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# Set fontsizes for plots etc.

# %%
from nb_api_kollokasjon_konk import *
# Out:
# Updated file `C:\Users\yoons\Documents\GitHub\Trawling\mods_meta.py`
# Updated file `C:\Users\yoons\Documents\GitHub\Trawling\collocations.py`

# %%
def declensions(wordbagfamily, pos = None):
    """Set pos to subst, verb or adj for limiting the inflectional forms"""
    if isinstance(pos, list):
        res = {key: list(set([w for infl_set in word_para(wordbagfamily[key]) for w in infl_set[2] if infl_set [1] in pos])) for key in wordbagfamily}
    elif isinstance( pos, str):
        res = {key: list(set([w for infl_set in word_para(wordbagfamily[key]) for w in infl_set[2] if infl_set [1] == pos])) for key in wordbagfamily}
    else:
        res = {key: list(set([w for infl_set in word_para(wordbagfamily[key]) for w in infl_set[2]])) for key in wordbagfamily}
    return res

# %%
def word_para(ws):
    res = word_paradigm_many(ws)
    for w in ws:
        if w not in [x[0] for x in res]:
            res.append([w, 'subs', [w]])
    return res

# %%
word_para(['Arbeidere', 'idretten'])
# Out:
# [['idretten', 'subs', ['idrett', 'idretten', 'idrettene', 'idretter']],
#  ['Arbeidere', 'subs', ['Arbeidere']]]

# %% [markdown]
# # Analyse

# %% [markdown]
# ### Sammenligning
#
# Det kan være greit å ha en samling ord for utvalg av et sett ord fra korpuset. Om vi satser på en standard forskjellsanalyse, tar vi utgangspunkt i de 200 000 mest frekvente ordene i bokhylla. Tallet kan økes.

# %%
tot = nb.frame(nb.totals(200000), 'tot')

# %%
nb.normalize_corpus_dataframe(tot)
# Out:
# True

# %% [markdown]
# ### Korpus
#
# Bygg et korpus på en eller annen måte. Her ser vi på 10 bøker hentet fra en bestemt periode, markert med emneordet 'krig'.

# %%
books = nb.book_corpus(ddk = '641%', lang= 'nob', period = (1990, 2010))

# %% [markdown]
# En kjapp oversikt over titler og forfatter.

# %%
books
# Out:
#               urn                           author  \
# 0   2013091638058                Hoffmann, Marc A.
# 1   2009050604056                    Newth, Philip
# 2   2015101648035             Hensley, Nina Dreyer
# 3   2013110508029                  Landmark, Marie
# 4   2014070906034
# 5   2013091638066                  Hess, Reinhardt
# 6   2007100304037                   Ainsworth, Jim
# 7   2014110448001
# 8   2014120807549
# 9   2008090500120
# 10  2011042608064  Hemmingsson, Elisabeth Ekstrand
# 11  2016021107505                Gabrielsen, Endre
# 12  2015050648005               Palmqvist, Susanne
# 13  2015052748018
# 14  2015082448316              Henriksen, Terje H.
# 15  2011080408016               McGraw, Phillip C.
# 16  2016070448125                        Ose, Leiv
# 17  2011021603013                Hofberg, Caroline
# 18  2011050308023                Atkins, Robert C.
# 19  2014110407673
#
#                                             title  year
# 0                                          Whisky  2009
# 1   Pytonslanger i eddik og stekte elefantsnabler  1996
# 2                                       Vintermat  2000
# 3                          Kogebog for Land og By  2002
# 4                         Norsk laks på alle bord  1992
# 5                                       Basic vin  2004
# 6                              Rødvin fra A til Å  1991
# 7                                          Småmat  2005
# 8                          Vidunderlig meksikansk  2007
# 9                  Poteten - tilbake på matbordet  1999
# 10     Damms beste oppskrifter på glutenfri bakst  2004
# 11                              Lam - helt enkelt  2005
# 12                     All verdens mat i mikroovn  1992
# 13                                      Desserter  2008
# 14                    H. Butler's bartender guide  2001
# 15                              Dr. Phils kokebok  2005
# 16               Godt for ganen, godt for hjertet  2001
# 17                                  Middelhavsmat  2009
# 18               Dr. Atkins' nye slankerevolusjon  2004
# 19                           Godt for diabetikere  2010

# %% [markdown]
# For å analysere samforekomster, telles ordene. Korpuset her tilsvarer subcorpus i Tangherlini&Leonard. Desto mindre jo bedre. Ordfrekvensene normaliseres i samme rennet.

# %%
df = nb.frame(nb.aggregate_urns(list(books.urn)))
nb.normalize_corpus_dataframe(df)
# Out:
# True

# %% [markdown]
# Når ordene sammenlignes med det som er forventet dukker det opp en slags tematisk struktur, som vi ser i neste output. Ordene er toppordene for de som utgjør en forskjell på korpuset sammenlignet med resten av bokhylla. Men merk at enkelte bøker kan dominere her, så derfor lurt å minske antallet, eller analysere bøkene en for en.
#
# Vi bruker korpus-ordene for å lage en tematisk struktur. Alt vi vet foreløpig er at hver og en av dem forekommer hyppigere i korpuset enn ellers i bokverdenen. Hvordan henger de sammen?

# %%
list(nb.frame_sort(nb.frame(df[0]/tot.tot)).head(20).index)
# Out:
# ['cocktailglass',
#  'cocktailbær',
#  'Vodka',
#  'Créme',
#  'Tequila',
#  'Shake',
#  'siles',
#  'dash',
#  'sitronskive',
#  'old-fashioned',
#  'Brandy',
#  'isbiter',
#  'Gin',
#  'Sila',
#  'Cocktail',
#  'Servering',
#  'avkjølt',
#  'SKRITT',
#  'ÅRLIG',
#  'Cabernet']

# %% [markdown]
# Ordene over kan vi bruke til å konstruere en graf basert på samforekomster. Kommandoen `nb.make_network_graph` tar en liste med ord og strukturer dem basert på samforekomst. Et ord W er koblet med en bue til et annet ord V, hvis W og V opptrer i samme avsnitt. Det gir en grafstruktur som kan visualiseres og analyseres.
#
# Her ser vi bare på ord som er mer eller mindre unike for tekstene i korpuset. Antallet ord bestemmes av parametret for `head()` i koden under. Her er den satt til 300, andre verdier gir flere ord, som vil øke størrels og antall på temaer.
#
# Ordene som skal brukes kunne i prinsippert vært hele korpuset, men for å komme i havn før nyttårsaften, og ikke sprenge datakapasiteten gjøres et utvalg. Forskjellig sett ord kan velges og gi andre resultat.

# %%
Gs = [nb.make_network_graph(str(u), list(nb.frame_sort(nb.frame(df[0]/tot.tot)).head(300).index)) for u in books.urn]

# %%
G = nx.Graph()
for g in Gs:
    G.add_edges_from(g.edges(data=True))

# %% [markdown]
# Grafen ser sånn ut. Med fargelagte noder for clustertilhørighet.

# %%
gnl.show_graph(G, spread = 1.5)

# %% [markdown]
# Nedenfor kan vi se på clustrene generert fra grafen (Louvain-metoden), som til syvende og sist er antatt å definere et aspekt ved den tematiske strukturen for korpuset. Tematikken er her basert på de viktigste ordene, beskrevet ovenfor. Andre detaljer vil komme frem ved å bruke andre ord som input, ordsekker laget ved kollokasjon for eksempel.
#
# En mulig svakhet ved clustringsalgoritmer er at de partisjonerer ordene, sånn at ord ikke forekommer i to eller fler clustre, til forskjell fra mixtur-modeller som LDA og NMF. Klikkstrukturene er bedre i så henseende. Vi bruker dem ikke nå i første omgang men se artikkelen om forskjellen på klikk og clustring ["Graph Analysis of Word Networks”](http://ceur-ws.org/Vol-2021/paper6.pdf)..
#
# Merkelappen på clustrene er hentet fra de mest sentrale ordene i clustret. Og hjelper litt med en begrepsmessig orden.

# %%
gnl.show_communities(G)
# Out:
# Servering-cognac :  Servering, cognac, likør, whiskey, tequila, bourbon, likøren, aperitiff, likører, Martini, ingrediens, whiskyen, alkoholstyrke, garnityr, Ricard, volumprosent, Peach, cocktails, calvados, destilleres, Margarita, blended, Frozen, Velvet, destillere, Shot, forbudstiden, EIER, ÅRLIG, Beam, STATUS, BETYR, Elgin
#
# sitronsaft-cl :  sitronsaft, cl, saften, kremfløte, Brandy, appelsinjuice, Créme, vanilje, dash, Cognac, Vodka, juice, Soda, Tequila, Whisky, Gin, ananas, Triple, Orange, Tørr, D.O, Skotsk, sukkerlake, Cream, grapefrukt, Bourbon, Midori, Portvin, Cassis, Søt, Calvados, Tia, sour, Coffee, Amour, Malibu, Comfort, Cocktail, Lemon, Punch, Bloody, Irsk, Absolut, Helles, 75,5, Chocolate, Melon, Flip, Delight, strøken, ★
#
# aroma-viner :  aroma, viner, eikefat, druene, vinene, Sauvignon, Cabernet, druen, rødviner, Cotes, fruktig, Bourgogne, Pinot, Merlot, cabernet, mosten, druesorter, hvitviner, Noir, garvesyre, Cote, NESTE, aromaen, Chianti, Beaujolais, SKRITT, Rioja, pinot, Shiraz, riesling, Ribera, Adige, alkoholinnhold, Viner, Barbera, Rødvin, Rosso, trefat, Douro, aromaer, crus, vinproduksjon, Beaune, Napa, Bergerac, Clos, ettersmak, Médoc, Highlands
#
# Sausen-Saus :  Sausen, Saus, koger, Liter, kogende, Gryden, koges, slaaes, kogt, Suppen, Gryde, Fedt, toppede, Peber, koge, Kilo, Kanel, steges, Ingefær, Fløde, Kjødet, Grød, Tøiet, Sila
#
# avkjølt-ingrediensene :  avkjølt, ingrediensene, isbiter, siles, Serveres, cocktailglass, helles, Topp, blender, old-fashioned, cocktailbær, hurtigmikser, sitronskive, Shake, flute, Garner, garneres, sugerør, ginger
#
# Tilsett-Dryss :  Tilsett, Dryss, hvitløk, olivenolje, chili, Stek, koriander, omrøring, finhakket, stekepanne, Skrell, avkjøl, Drypp, vårløk, kjøkkenmaskin, Fres, stekeovnen, fyllet, kokekar, sjalottløk, oregano, spisskummen, soyasaus, Strø, limesaft, tykkbunnet, røren, kjøkkenpapir, bladpersille, kokekaret, fedd, langpanne, krm, forvarmet, kajennepepper, chilipulver, nykvernet, buljongen, Anrett, bakepapir, olivenoljen, hullsleiv, finhakk, smakene, gjennomstekt, salsa, paprikaen, chilisaus, paprikapulver, PORSJONER, romtemperert, sesamfrø, Smuldre, oppbevar, lettrømme, hvitvinseddik, mikser, stekeplate, Iss, hvitløkfedd, kesam, fiskesaus, eggehvitene, grovhakket, kjøkkenhåndkle, chilien, Kjevle, parmesanost, soltørkede, sitronbåter, tortilla, paprikaene, avocado, laksefilet, Idl, karbohydrater, gjæren, butterdeig, fetaost, grønnsakbuljong, kikerter, squashen, grovmalt, kremfløten, sammenvispet, strimlet, kremost, stavmikser, Karbohydrater, jerngryte, kanelstang, PERSONER, koketiden, skivet, nudlene, bakebord, gjennomkokt, strøsukker, Proteiner, pesto, nyrevet, kakaopulver, Fiber, tilberedning, kremet, IV4, grillede, Sprø, Kolesterol, Steking, bokhvete, couscous, Natrium, tørrgjær, Atkins, glutenfri, kolesterolet, Ovnstemperatur, Ingredienser, terter
#
# Koketid-Tilberedning :  Koketid, Tilberedning

# %% [markdown]
# ### Evaluering, tråling
#
# Temaene generert over kan analyseres på selve korpuset, eller på et annet større korpus. Først ser vi på selve korpust

# %% [markdown]
# Temaene hentes ut som en familie ordklasser

# %%
themes = gnl.community_dict(G)

# %% [markdown]
# For å få med bøyningsvarianter, legger vi til infleksjonsformer for ord som har det.

# %%
themes_plus = declensions(themes)

# %% [markdown]
# ### Gå gjennom bøker og tell opp temaene

# %%
evals = nb.wordbag_eval(themes_plus, list(books.urn)).astype(int)

# %%
evals.style.background_gradient(axis = 0)
# Out:
# <style  type="text/css" >
#     #T_1f1afadc_291f_11eb_8431_985fd3509bc7row0_col0 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row0_col3 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row0_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row1_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row1_col2 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row1_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row1_col4 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row1_col5 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row1_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row1_col7 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row2_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row2_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row2_col2 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row2_col3 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row2_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row2_col5 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row2_col6 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row2_col7 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row3_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row3_col1 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row3_col2 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row3_col3 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row3_col4 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row3_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row3_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row3_col7 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row4_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row4_col1 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row4_col2 {
#             background-color:  #76aad0;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row4_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row4_col4 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row4_col5 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row4_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row4_col7 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row5_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row5_col1 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row5_col2 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row5_col3 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row5_col4 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row5_col5 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row5_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row5_col7 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row6_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row6_col2 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row6_col3 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row6_col4 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row6_col5 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row6_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row6_col7 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row7_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row7_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row7_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_1f1afadc_291f_11eb_8431_985fd3509bc7row7_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;

# %% [markdown]
# ### Evaluere mot et skjønnlitterært korpus fra samme era.
#
# Evalueringen er uavhengig av hvordan temaordene er laget. De kan lages for hånd, genereres med LDA, eller som over, hentet fra grafer. Evalueringen teller opp ordsekkfamilien over et sett ord.

# %%
testkorpus = nb.book_corpus(ddk = '839%', period = (1990, 2010), limit = 20000)

# %%
testeval = nb.wordbag_eval(themes_plus, list(testkorpus.urn)).astype(int)

# %% [markdown]
# Korpuset er litt for stort til visualisering, så sorterer på et trekk og tar ut de 50 beste

# %%
testeval.sort_values(by = 'snitt', ascending = False).head(50).style.background_gradient(axis = 0)
# Out:
# <style  type="text/css" >
#     #T_24319808_291f_11eb_a03c_985fd3509bc7row0_col0 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row0_col1 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row0_col2 {
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row0_col3 {
#             background-color:  #02395a;
#             color:  #f1f1f1;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row0_col4 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row0_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row1_col0 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row1_col1 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row1_col2 {
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row1_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row1_col4 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row1_col5 {
#             background-color:  #03446a;
#             color:  #f1f1f1;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row1_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row1_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row2_col0 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row2_col1 {
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row2_col2 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row2_col3 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row2_col4 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row2_col5 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row2_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row2_col7 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row3_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row3_col2 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row3_col3 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row3_col5 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row3_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row3_col7 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row4_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row4_col1 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row4_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row4_col3 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row4_col5 {
#             background-color:  #045788;
#             color:  #f1f1f1;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row4_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row4_col7 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row5_col0 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row5_col1 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row5_col2 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row5_col3 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row5_col4 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row5_col5 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row5_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row5_col7 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row6_col0 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row6_col1 {
#             background-color:  #2a88bc;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row6_col2 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row6_col3 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row6_col4 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row6_col5 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row6_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row6_col7 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row7_col0 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row7_col1 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row7_col2 {
#             background-color:  #c8cde4;
#             color:  #000000;
#         }    #T_24319808_291f_11eb_a03c_985fd3509bc7row7_col3 {
#             background-color:  #ece7f2;
#             color:  #000000;
