# %% [markdown]
# # TM
#
# Temamodellering basert på clustring, klikk og grafanalyse.
#
# Her ser vi på
# 1. Bygg et korpus
# 1. Hvordan hente ut tematiske strukturer fra korpus
# 1. Hvordan evaluere temaer mot et større korpus
#
# Om de tematisk strukturene kommer et annetsteds fra, så kan evalueringen fremdeles benyttes, og evalueres mot bokhyllas data.

# %% [markdown]
# ### først litt kode for å komme i gang

# %%
import json
import pandas as pd
import dhlab.module_update as mu
mu.update('mods_meta')
import mods_meta as mm
import dhlab.nbtext as nb
import re
from IPython.display import Markdown, display
from collections import Counter
from dhlab.nbtokenizer import tokenize
import networkx as nx
import dhlab.graph_networkx_louvain as gnl
import datetime
from scipy.spatial.distance import cosine
from sklearn.metrics.pairwise import cosine_similarity, cosine_distances
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import json
mu.update('wordbank')
# Out:
# Updated file `C:\Users\yoons\Documents\GitHub\Trawling\mods_meta.py`
# Updated file `C:\Users\yoons\Documents\GitHub\Trawling\wordbank.py`

# %%
from wordbank import word_paradigm_many, word_lemma_many, word_form_many

# %%
mu.css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Merriweather|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Merriweather';
# 	color: DarkSlateGray;
# }
#
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# Set fontsizes for plots etc.

# %%
from nb_api_kollokasjon_konk import *
# Out:
# Updated file `C:\Users\yoons\Documents\GitHub\Trawling\mods_meta.py`
# Updated file `C:\Users\yoons\Documents\GitHub\Trawling\collocations.py`

# %%
def declensions(wordbagfamily, pos = None):
    """Set pos to subst, verb or adj for limiting the inflectional forms"""
    if isinstance(pos, list):
        res = {key: list(set([w for infl_set in word_para(wordbagfamily[key]) for w in infl_set[2] if infl_set [1] in pos])) for key in wordbagfamily}
    elif isinstance( pos, str):
        res = {key: list(set([w for infl_set in word_para(wordbagfamily[key]) for w in infl_set[2] if infl_set [1] == pos])) for key in wordbagfamily}
    else:
        res = {key: list(set([w for infl_set in word_para(wordbagfamily[key]) for w in infl_set[2]])) for key in wordbagfamily}
    return res

# %%
def word_para(ws):
    res = word_paradigm_many(ws)
    for w in ws:
        if w not in [x[0] for x in res]:
            res.append([w, 'subs', [w]])
    return res

# %%
word_para(['Arbeidere', 'idretten'])
# Out:
# [['idretten', 'subs', ['idrett', 'idretten', 'idrettene', 'idretter']],
#  ['Arbeidere', 'subs', ['Arbeidere']]]

# %% [markdown]
# # Analyse

# %% [markdown]
# ### Sammenligning
#
# Det kan være greit å ha en samling ord for utvalg av et sett ord fra korpuset. Om vi satser på en standard forskjellsanalyse, tar vi utgangspunkt i de 200 000 mest frekvente ordene i bokhylla. Tallet kan økes.

# %%
tot = nb.frame(nb.totals(200000), 'tot')

# %%
nb.normalize_corpus_dataframe(tot)
# Out:
# True

# %% [markdown]
# ### Korpus
#
# Bygg et korpus på en eller annen måte. Her ser vi på 10 bøker hentet fra en bestemt periode, markert med emneordet 'krig'.

# %%
books_ = nb.book_corpus(author = 'mykle%agnar%', lang= 'nob', period = (1940, 2010))

# %% [markdown]
# En kjapp oversikt over titler og forfatter.

# %%
books_
# Out:
#               urn        author                      title  year
# 0   2016020808126  Mykle, Agnar   Sangen om den røde rubin  2000
# 1   2014111108298  Mykle, Agnar       Lasso rundt fru Luna  2007
# 2   2008072504129  Mykle, Agnar           Samlede noveller  1996
# 3   2008021104057  Mykle, Agnar             Samlede verker  1994
# 4   2012020208192  Mykle, Agnar             Kors på halsen  1958
# 5   2008020701019  Mykle, Agnar             Samlede verker  1994
# 6   2014072108181  Mykle, Agnar       Lasso rundt fru Luna  2006
# 7   2008012100052  Mykle, Agnar             Samlede verker  1994
# 8   2007052404016  Mykle, Agnar   Sangen om den røde rubin  1967
# 9   2008072800017  Mykle, Agnar          mann og hans vask  1996
# 10  2009062400001  Mykle, Agnar       Lasso rundt fru Luna  1998
# 11  2008020504106  Mykle, Agnar             Samlede verker  1994
# 12  2011111608114  Mykle, Agnar  Tyven, tyven skal du hete  1951
# 13  2008021104029  Mykle, Agnar   Sangen om den røde rubin  1995
# 14  2009062900060  Mykle, Agnar                Noveller II  2000
# 15  2011070805071  Mykle, Agnar           Kjære lille Moff  2004
# 16  2014010308002  Mykle, Agnar      Morgen i appelsingult  1951
# 17  2008022200094  Mykle, Agnar  Tyven, tyven skal du hete  1995
# 18  2009012000014  Mykle, Agnar           v og annen prosa  1998
# 19  2009032304054  Mykle, Agnar                    Rubicon  1999

# %%
books = books_[books_.urn.isin([2016020808126,2009032304054,2009062400001])]

# %%
books
# Out:
#               urn        author                     title  year
# 0   2016020808126  Mykle, Agnar  Sangen om den røde rubin  2000
# 10  2009062400001  Mykle, Agnar      Lasso rundt fru Luna  1998
# 19  2009032304054  Mykle, Agnar                   Rubicon  1999

# %% [markdown]
# For å analysere samforekomster, telles ordene. Korpuset her tilsvarer subcorpus i Tangherlini&Leonard. Desto mindre jo bedre. Ordfrekvensene normaliseres i samme rennet.
#
# Her ser vi på trilogien Rubicon, Lass og Sangen

# %%
df = nb.frame(nb.aggregate_urns(list(books.urn)))
nb.normalize_corpus_dataframe(df)
# Out:
# True

# %% [markdown]
# Når ordene sammenlignes med det som er forventet dukker det opp en slags tematisk struktur, som vi ser i neste output. Ordene er toppordene for de som utgjør en forskjell på korpuset sammenlignet med resten av bokhylla. Men merk at enkelte bøker kan dominere her, så derfor lurt å minske antallet, eller analysere bøkene en for en.
#
# Vi bruker korpus-ordene for å lage en tematisk struktur. Alt vi vet foreløpig er at hver og en av dem forekommer hyppigere i korpuset enn ellers i bokverdenen. Hvordan henger de sammen?

# %%
selection_ = word_form_many(list(nb.frame_sort(nb.frame(df[0]/tot.tot)).head(700).index))
selection = [x[0] for x in selection_ if 'subs' in x[1] or 'verb' in x[1]]

# %%
selection
# Out:
# ['skjensel',
#  'hjelpelærer',
#  'hjelpelærer',
#  'hjelpelærer',
#  'bestyreren',
#  'bestyreren',
#  'bestyreren',
#  'håndflate',
#  'håndflate',
#  'hurtigruten',
#  'øyenlokk',
#  'øyenlokk',
#  'lasso',
#  'sosialist',
#  'katetret',
#  'skaker',
#  'dansemoro',
#  'dansemoro',
#  'gyste',
#  'snadde',
#  'snadde',
#  'ridestøvler',
#  'lokalbåten',
#  'hybelen',
#  'tommeltotten',
#  'lassoen',
#  'lettsinn',
#  'lettsinn',
#  'handelsskole',
#  'overleppe',
#  'overleppe',
#  'vanmakt',
#  'vanmakt',
#  'handelsskolen',
#  'tolleren',
#  'tolleren',
#  'tolleren',
#  'harske',
#  'verdensrom',
#  'verdensrom',
#  'gymnasier',
#  'frikvarterene',
#  'kvidder',
#  'kvidder',
#  'forkjølt',
#  'ranket',
#  'ranket',
#  'ranket',
#  'ranket',
#  'underarmer',
#  'sangkoret',
#  'rumpen',
#  'rumpen',
#  'brystholderen',
#  'brystholderen',
#  'brystholderen',
#  'divanen',
#  'smilerynker',
#  'smilerynker',
#  'telefonboksen',
#  'nachspiel',
#  'nachspiel',
#  'riksspråk',
#  'riksspråk',
#  'krykken',
#  'hårlokken',
#  'henrykte',
#  'gnikket',
#  'gnikket',
#  'gnikket',
#  'gnikket',
#  'hikster',
#  'handelsfag',
#  'handelsfag',
#  'siderommet',
#  'underkjeve',
#  'stensilerte',
#  'belesset',
#  'belesset',
#  'køyen',
#  'skolebestyrer',
#  'skolebestyrer',
#  'skolebestyrer',
#  'blaff',
#  'blaff',
#  'blaff',
#  'blaff',
#  'rubin',
#  'svelger',
#  'svelger',
#  'studenten',
#  'unnfly',
#  'unnfly',
#  'overmunnen',
#  'fullbragt',
#  'hornbriller',
#  'hornbriller',
#  'sosialister',
#  'taktstokken',
#  'mavesår',
#  'mavesår',
#  'hybel',
#  'forsmedelse',
#  'middagslur',
#  'jernbaneskinner',
#  'jernbaneskinner',
#  'takrennen',
#  'festtaler',
#  'auditoriet',
#  'armbåndsur',
#  'armbåndsur',
#  'midje',
#  'midje',
#  'skandinav',
#  'brekket',
#  'brekket',
#  'brekket',
#  'uselviskhet',
#  'uselviskhet',
#  'forsovet',
#  'fløytet',
#  'fløytet',
#  'fløytet',
#  'fløytet',
#  'fløytet',
#  'håndtrykk',
#  'håndtrykk',
#  'fornemmet',
#  'fornemmet',
#  'slappes',
#  'plirte',
#  'vaskevannsfatet',
#  'underliv',
#  'underliv',
#  'harmonilære',
#  'harmonilære',
#  'grafset',
#  'grafset',
#  'krampegråt',
#  'mimret',
#  'mimret',
#  'hyttetur',
#  'halset',
#  'halset',
#  'bøyet',
#  'bøyet',
#  'gymnasiet',
#  'forhjulet',
#  'hurtigrute',
#  'hurtigrute',
#  'knottene',
#  'hedrer',
#  'hedrer',
#  'aristokrat',
#  'brunst',
#  'halvlyset',
#  'konverserte',
#  'fotsåler',
#  'silkestrømper',
#  'silkestrømper',
#  'fadese',
#  'skotte',
#  'skotte',
#  'svimlet',
#  'svimlet',
#  'fyllepenn',
#  'bakhjulet',
#  'vestelommen',
#  'gammelost',
#  'dulgt',
#  'barberkniv',
#  'forsonte',
#  'lydd',
#  'lydd',
#  'lydd',
#  'lydd',
#  'dynen',
#  'sosialistene',
#  'vindusposten',
#  'barbar',
#  'billettluken',
#  'kajakken',
#  'hårsbredd',
#  'vellysten',
#  'sordin',
#  'veldet',
#  'smokingen',
#  'bukselomme',
#  'bukselomme',
#  'fiolinen',
#  'køye',
#  'køye',
#  'køye',
#  'knickers',
#  'frikvarteret',
#  'landgangen',
#  'armbåndsuret',
#  'meteorolog',
#  'meteorologene',
#  'ødet',
#  'ødet',
#  'ødet',
#  'skjendet',
#  'skjendet',
#  'fortann',
#  'fortann',
#  'foresvevet',
#  'foresvevet',
#  'blomsterpotte',
#  'blomsterpotte',
#  'stortåen',
#  'skotter',
#  'skotter',
#  'fenriken',
#  'skipskaptein',
#  'favntaket',
#  'svelge',
#  'bukseben',
#  'bukseben',
#  'gyser',
#  'gyser',
#  'gyser',
#  'gyser',
#  'debattant',
#  'høyskolen',
#  'konvoluttene',
#  'værmelding',
#  'værmelding',
#  'dunkene',
#  'dunkene',
#  'fniser',
#  'svev',
#  'svev',
#  'svev',
#  'svev',
#  'besverger',
#  'døgenikt',
#  'pøl',
#  'underbitt',
#  'underbitt',
#  'draug',
#  'henførelse',
#  'henrykt',
#  'sjøormen',
#  'dobbeltseng',
#  'dobbeltseng',
#  'hakekors',
#  'hakekors',
#  'alpelue',
#  'alpelue',
#  'hovedkarakter',
#  'snork',
#  'snork',
#  'snork',
#  'snork',
#  'snork',
#  'svada',
#  'pensjonatet',
#  'vemod',
#  'vemod',
#  'skvulper',
#  'kontordamen',
#  'innkasserte',
#  'galten',
#  'sitrer',
#  'yttertøyet',
#  'adjunkten',
#  'fnis',
#  'fnis',
#  'fnis',
#  'foxtrot',
#  'koldtbord',
#  'koldtbord',
#  'sosialøkonomi',
#  'bondegårdene',
#  'fippskjegg',
#  'fippskjegg',
#  'dådyr',
#  'dådyr',
#  'holmgang',
#  'skrivemaskiner',
#  'skrivemaskiner',
#  'glipe',
#  'glipe',
#  'glipe',
#  'gløtter',
#  'gløtter',
#  'innbegrepet',
#  'hodeputen',
#  'malstrømmen',
#  'pjolter',
#  'pjolter',
#  'pjolter',
#  'forfrysning',
#  'forfrysning',
#  'splintres',
#  'divan',
#  'lyske',
#  'lyske',
#  'strømpelesten',
#  'sitret',
#  'sitret',
#  'innlatt',
#  'kateteret',
#  'gullstøv',
#  'gullstøv',
#  'skjødet',
#  'kontrabande',
#  'spanskrør',
#  'spanskrør',
#  'kimono',
#  'gullringen',
#  'barduner',
#  'barduner',
#  'drikkepenger',
#  'favntak',
#  'favntak',
#  'ølglasset',
#  'stolsetet',
#  'friplass',
#  'tvillingsøster',
#  'tvillingsøster',
#  'vinterfrakk',
#  'innvoller',
#  'subber',
#  'subber',
#  'subber',
#  'subber',
#  'sementert',
#  'turnsko',
#  'turnsko',
#  'kjakene',
#  'rhinskvin',
#  'pinsetten',
#  'uniformsluen',
#  'gatehjørnet',
#  'munnviker',
#  'munnviker',
#  'saksofon',
#  'forelskelsen',
#  'underarm',
#  'slikker',
#  'slikker',
#  'karamellpudding',
#  'unnslo',
#  'absolutter',
#  'motorsykkel',
#  'lyspærene',
#  'lyspærene',
#  'klaske',
#  'handelsrett',
#  'sjøstøvler',
#  'putevaret',
#  'gymnasiast',
#  'snadden',
#  'bandolær',
#  'bandolær',
#  'mustasje',
#  'fersken',
#  'besvangret',
#  'besvangret',
#  'halvmåner',
#  'barberhøvel',
#  'plattfot',
#  'nesebor',
#  'nesebor',
#  'krypt',
#  'svanene',
#  'svanene',
#  'andakt',
#  'andakt',
#  'vindmølle',
#  'vindmølle',
#  'stolpret',
#  'stolpret',
#  'eføyen',
#  'billedbok',
#  'billedbok',
#  'øyenlokkene',
#  'kompendier',
#  'ekteskaper',
#  'eventyrbok',
#  'eventyrbok',
#  'murrer',
#  'slipsknuten',
#  'askebeger',
#  'askebeger',
#  'gymnasiaster',
#  'pinnestolen',
#  'hikste',
#  'motorsykkelen',
#  'muser',
#  'pludrer',
#  'periskop',
#  'periskop',
#  'morsomheter',
#  'morsomheter',
#  'befølte',
#  'halvflaske',
#  'halvflaske',
#  'emissærer',
#  'langfinger',
#  'franko',
#  'vaskekjelleren',
#  'vaskekjelleren',
#  'vaskekjelleren',
#  'overfaller',
#  'hjemsøkes',
#  'hulker',
#  'velder',
#  'høvelbenken',
#  'tollerne',
#  'tollerne',
#  'tollerne',
#  'forelesningene',
#  'forelesningene',
#  'buksen',
#  'mave',
#  'mave',
#  'postere',
#  'postere',
#  'kaféen',
#  'lesesalen',
#  'mykner',
#  'mykner',
#  'mykner',
#  'mykner',
#  'trykkfeil',
#  'trykkfeil',
#  'fotsåle',
#  'langfingeren',
#  'barberkniven',
#  'telegrammet',
#  'skumpet',
#  'skumpet',
#  'skumpet',
#  'lyktestolpe',
#  'pyjamasen',
#  'forføye',
#  'forføye',
#  'kremter',
#  'mulden',
#  'snyter',
#  'snyter',
#  'snyter',
#  'snyter',
#  'snyter',
#  'seidel',
#  'øder',
#  'øder',
#  'øder',
#  'øder',
#  'øder',
#  'øder',
#  'morsomhet',
#  'morsomhet',
#  'blomsterbuketten',
#  'handelsgymnasium',
#  'besvarelsene',
#  'brystholder',
#  'brystholder',
#  'brystholder',
#  'kubikk',
#  'kubikk',
#  'helskjegg',
#  'helskjegg',
#  'ekspeditrisen',
#  'ryster',
#  'nedverdigelse',
#  'orgasmer',
#  'klassekameratene',
#  'gatekryss',
#  'gatekryss',
#  'gamlefar',
#  'oljehyre',
#  'oljehyre',
#  'kirkeminister',
#  'kirkeminister',
#  'kirkeminister',
#  'voksduk',
#  'slikkerier',
#  'håndbaken',
#  'folketaler',
#  'folketaler',
#  'folketaler',
#  'overmennesket',
#  'avskyen',
#  'ølglass',
#  'ølglass',
#  'verdensmann',
#  'kontrolløren',
#  'lommelerke',
#  'lommelerke',
#  'væten',
#  'væten',
#  'minte',
#  'minte',
#  'danseskolen',
#  'hunger',
#  'hunger',
#  'hunger',
#  'kjever',
#  'glefs',
#  'glefs',
#  'glefs',
#  'glefs',
#  'glefs',
#  'fløytene',
#  'fløytene',
#  'fløytene',
#  'skoleporten',
#  'armlenet',
#  'kinnbenene',
#  'fiolin',
#  'strikkepinner',
#  'vanndråpene',
#  'asjett',
#  'handelsreisende',
#  'handelsreisende',
#  'nattbord',
#  'nattbord',
#  'korreks',
#  'dagdrømmen',
#  'snippen',
#  'bedriftsøkonomi',
#  'trikken',
#  'gasje']

# %% [markdown]
# Ordene over kan vi bruke til å konstruere en graf basert på samforekomster. Kommandoen `nb.make_network_graph` tar en liste med ord og strukturer dem basert på samforekomst. Et ord W er koblet med en bue til et annet ord V, hvis W og V opptrer i samme avsnitt. Det gir en grafstruktur som kan visualiseres og analyseres.
#
# Her ser vi bare på ord som er mer eller mindre unike for tekstene i korpuset. Antallet ord bestemmes av parametret for `head()` i koden under. Her er den satt til 300, andre verdier gir flere ord, som vil øke størrels og antall på temaer.
#
# Ordene som skal brukes kunne i prinsippert vært hele korpuset, men for å komme i havn før nyttårsaften, og ikke sprenge datakapasiteten gjøres et utvalg. Forskjellig sett ord kan velges og gi andre resultat.

# %%
Gs = [nb.make_network_graph(str(u), selection) for u in books.urn]

# %%
G = nx.Graph()
for g in Gs:
    G.add_edges_from(g.edges(data=True))

# %% [markdown]
# Grafen ser sånn ut. Med fargelagte noder for clustertilhørighet.

# %%
gnl.show_graph(G)

# %% [markdown]
# Nedenfor kan vi se på clustrene generert fra grafen (Louvain-metoden), som til syvende og sist er antatt å definere et aspekt ved den tematiske strukturen for korpuset. Tematikken er her basert på de viktigste ordene, beskrevet ovenfor. Andre detaljer vil komme frem ved å bruke andre ord som input, ordsekker laget ved kollokasjon for eksempel.
#
# En mulig svakhet ved clustringsalgoritmer er at de partisjonerer ordene, sånn at ord ikke forekommer i to eller fler clustre, til forskjell fra mixtur-modeller som LDA og NMF. Klikkstrukturene er bedre i så henseende. Vi bruker dem ikke nå i første omgang men se artikkelen om forskjellen på klikk og clustring ["Graph Analysis of Word Networks”](http://ceur-ws.org/Vol-2021/paper6.pdf)..
#
# Merkelappen på clustrene er hentet fra de mest sentrale ordene i clustret. Og hjelper litt med en begrepsmessig orden.

# %%
gnl.show_communities(G)
# Out:
# dynen-hunger :  dynen, hunger, fniser, slikker, sosialøkonomi, askebeger, gyser, slappes, barbar, rubin, sitrer, armbåndsur, orgasmer, svimlet, køye, munnviker, koldtbord, rhinskvin, fersken, køyen, karamellpudding, absolutter, ølglass, forsovet, halvmåner, kontrabande, besvarelsene, voksduk, pludrer, befølte
#
# henrykt-sosialist :  henrykt, sosialist, fiolin, sosialister, hurtigruten, fiolinen, sosialistene, ølglasset, rumpen, vinterfrakk, gymnasiast, sordin, dobbeltseng, nachspiel, vanmakt, kjakene, festtaler, forelskelsen, debattant, stortåen, friplass, pjolter, mimret, gullringen, forsmedelse, belesset, foxtrot, jernbaneskinner, drikkepenger, plirte, værmelding, uselviskhet, siderommet, overmennesket, skandinav, snyter, murrer, lettsinn, saksofon, vindmølle, fløytene, pinnestolen, kaféen, sjøormen, subber, forfrysning, fadese, sementert, døgenikt
#
# svelger-blaff :  svelger, blaff, fornemmet, innvoller, divan, underliv, dulgt, armbåndsuret, skotter, tommeltotten, kajakken, innbegrepet, hikster, silkestrømper, skvulper, kremter, gløtter, harske, favntaket, vindusposten, svelge, kjever, klaske, brunst, folketaler, underarmer, krypt, lyske, korreks, fnis, fullbragt, asjett, væten, veldet, forsonte, skjendet, besverger, bondegårdene, vellysten, sangkoret
#
# forelesningene-auditoriet :  forelesningene, auditoriet, lesesalen, bedriftsøkonomi, katetret, pyjamasen, skjødet, forkjølt, trykkfeil, bukseben, grafset, klassekameratene, meteorologene, stolsetet, kvidder, frikvarteret, meteorolog, kompendier, ødet, hulker, stensilerte, verdensrom, takrennen, handelsrett, hårlokken, pinsetten, gnikket
#
# studenten-andakt :  studenten, andakt, buksen, nesebor, henrykte, aristokrat, langfinger, forhjulet, ridestøvler, vemod, lasso, handelsreisende, hornbriller, barberkniv, håndbaken, svada, ranket, tolleren, lassoen, krampegråt, taktstokken, emissærer, hakekors, knickers, svev, telefonboksen, barberhøvel, mykner, konverserte, bandolær, nedverdigelse, vaskevannsfatet, barberkniven, tvillingsøster, dagdrømmen
#
# skjensel-minte :  skjensel, minte, bestyreren, trikken, kateteret, snadde, høyskolen, gasje, pøl, middagslur, mustasje, hjelpelærer, lokalbåten, verdensmann, alpelue, avskyen, innlatt, morsomheter, skrivemaskiner, hovedkarakter, morsomhet, sjøstøvler, innkasserte, vestelommen, snadden, fenriken, hyttetur, skumpet, eventyrbok, skolebestyrer, harmonilære, gatehjørnet, adjunkten, kontrolløren, krykken, oljehyre
#
# hybelen-hybel :  hybelen, hybel, divanen, gyste, bøyet, mave, skotte, sitret, midje, strømpelesten, blomsterpotte, overleppe, skaker, dansemoro, mavesår, halvflaske, dådyr, frikvarterene, vanndråpene, håndflate, underkjeve, kimono, favntak, gymnasiet, telegrammet, langfingeren, gymnasier, halset, turnsko, overmunnen, hedrer, yttertøyet, kontordamen, splintres, halvlyset, brystholder, brystholderen, hårsbredd, snippen, knottene, holmgang, armlenet, vaskekjelleren, hikste, handelsgymnasium, lyktestolpe, smokingen, høvelbenken, unnfly, kirkeminister, fortann, forføye, bukselomme
#
# motorsykkel-pensjonatet :  motorsykkel, pensjonatet, gatekryss, fyllepenn, muser, smilerynker, glefs, malstrømmen, landgangen, uniformsluen, kubikk, barduner, fløytet, motorsykkelen, draug, bakhjulet
#
# handelsskole-underarm :  handelsskole, underarm, gammelost, handelsskolen, håndtrykk, underbitt, handelsfag, franko
#
# øyenlokk-ryster :  øyenlokk, ryster, hodeputen, nattbord, øyenlokkene, kinnbenene, henførelse, gymnasiaster, glipe, billedbok, fippskjegg, helskjegg, brekket, putevaret

# %% [markdown]
# ### Evaluering, tråling
#
# Temaene generert over kan analyseres på selve korpuset, eller på et annet større korpus. Først ser vi på selve korpust

# %% [markdown]
# Temaene hentes ut som en familie ordklasser

# %%
themes = gnl.community_dict(G)

# %% [markdown]
# For å få med bøyningsvarianter, legger vi til infleksjonsformer for ord som har det.

# %%
themes_plus = declensions(themes)

# %% [markdown]
# ### Gå gjennom bøker og tell opp temaene

# %%
evals = nb.wordbag_eval(themes_plus, list(books_.urn)).astype(int)

# %%
evals.style.background_gradient(axis = 0)
# Out:
# <style  type="text/css" >
#     #T_01d7df18_296c_11eb_83c9_985fd3509bc7row0_col0 {
#             background-color:  #04649e;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row0_col1 {
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row0_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row0_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row0_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row0_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row1_col0 {
#             background-color:  #157ab5;
#             color:  #000000;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row1_col1 {
#             background-color:  #2c89bd;
#             color:  #000000;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row1_col2 {
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row1_col3 {
#             background-color:  #045b8f;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row1_col4 {
#             background-color:  #045788;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row1_col5 {
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row1_col6 {
#             background-color:  #045b8f;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row1_col7 {
#             background-color:  #046097;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row1_col8 {
#             background-color:  #034973;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row1_col9 {
#             background-color:  #034c78;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row1_col10 {
#             background-color:  #045788;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row2_col0 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row2_col1 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row2_col2 {
#             background-color:  #046299;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row2_col3 {
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row2_col4 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row2_col5 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row2_col6 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row2_col7 {
#             background-color:  #04649d;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row2_col8 {
#             background-color:  #045788;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row2_col9 {
#             background-color:  #03517e;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row2_col10 {
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row3_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row3_col2 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row3_col3 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row3_col4 {
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row3_col5 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row3_col6 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row3_col7 {
#             background-color:  #197db7;
#             color:  #000000;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row3_col8 {
#             background-color:  #2c89bd;
#             color:  #000000;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row3_col9 {
#             background-color:  #4c99c5;
#             color:  #000000;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row3_col10 {
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row4_col0 {
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row4_col1 {
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row4_col2 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row4_col3 {
#             background-color:  #197db7;
#             color:  #000000;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row4_col4 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row4_col5 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row4_col6 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row4_col7 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row4_col8 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row4_col9 {
#             background-color:  #4094c3;
#             color:  #000000;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row4_col10 {
#             background-color:  #167bb6;
#             color:  #000000;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row5_col0 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row5_col1 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row5_col2 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row5_col3 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_01d7df18_296c_11eb_83c9_985fd3509bc7row5_col4 {
#             background-color:  #4697c4;
#             color:  #000000

# %% [markdown]
# ### Evaluere mot et skjønnlitterært korpus fra samme era.
#
# Evalueringen er uavhengig av hvordan temaordene er laget. De kan lages for hånd, genereres med LDA, eller som over, hentet fra grafer. Evalueringen teller opp ordsekkfamilien over et sett ord.

# %%
testkorpus = nb.book_corpus(ddk = '839%', period = (1990, 2010), limit = 20)

# %%
testeval = nb.wordbag_eval(themes_plus, list(testkorpus.urn)).astype(int)

# %% [markdown]
# Korpuset er litt for stort til visualisering, så sorterer på et trekk og tar ut de 50 beste

# %%
testeval.sort_values(by = 'snitt', ascending = False).head(50).style.background_gradient(axis = 0)
# Out:
# <style  type="text/css" >
#     #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row0_col0 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row0_col2 {
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row0_col4 {
#             background-color:  #4094c3;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row0_col6 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row0_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row0_col8 {
#             background-color:  #045382;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row0_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row0_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row1_col0 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row1_col1 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row1_col3 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row1_col4 {
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row1_col5 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row1_col6 {
#             background-color:  #056fae;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row1_col7 {
#             background-color:  #4897c4;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row1_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row1_col9 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row1_col10 {
#             background-color:  #03456c;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row2_col0 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row2_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row2_col3 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row2_col4 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row2_col5 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row2_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row2_col7 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row2_col8 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row2_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row2_col10 {
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row3_col0 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row3_col1 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row3_col3 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row3_col4 {
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row3_col5 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row3_col6 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row3_col7 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row3_col8 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row3_col9 {
#             background-color:  #1c7fb8;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row3_col10 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row4_col0 {
#             background-color:  #4094c3;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row4_col1 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row4_col2 {
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row4_col3 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row4_col5 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row4_col6 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row4_col7 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row4_col8 {
#             background-color:  #045382;
#             color:  #f1f1f1;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row4_col9 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row4_col10 {
#             background-color:  #88b1d4;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row5_col0 {
#             background-color:  #2c89bd;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row5_col1 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row5_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row5_col3 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_035ae5cc_296c_11eb_afbc_985fd3509bc7row5_col4 {
#             background-color:  #2786bb;
#             color:  #000000

# %%
mdata = [nb.metadata(u) for u in testeval.sort_values(by = 'snitt', ascending = False).head(50).index]

# %%
nb.frame(mdata)
# Out:
#                                                     0
# 0   [2008111304008, Haavardsholm, Espen, 2001, Øst...
# 1   [2013121805092, Bjørnstad, Ketil, 2009, Til mu...
# 2   [2009033100083, Blad, Hans Petter, 2002, I sky...
# 3   [2013102505128, Staalesen, Gunnar, 2008, Som i...
# 4   [2008020800064, Johannessen, Arnulf, 1995, Bak...
# 5   [2014042208026, Lerum, May Grethe, 2009, Nymån...
# 6   [2014011708027, Lie, Embla, 2005, verden av mu...
# 7   [2014012906047, Linde, Heidi, 2009, Sug, , Gyl...
# 8   [2013012206022, Nicolaysen, Marit, 2007, Svein...
# 9   [2014030308085, Lindell, Unni, 2007, To fruer ...
# 10  [2012072709024, Ibsen, Henrik, 2002, Keiser og...
# 11  [2009012704026, Lunde, Inger-Margrethe, 2002, ...
# 12  [2013022606114, Gotthardt, Peter, 2010, Farlig...
# 13  [2008091500005, Kjelsen, Reidar, 1998, Flink b...
# 14  [2015112508311, Brantzeg, Mette, 2002, Medan v...
# 15  [2014070406040, Oshaug, Aase Lillemo, 2004, Ti...

# %% [markdown]
# Tema som komplekse tegn. Hva er det som gir treff fra et tema/cluster i nye bøker?

# %%
def check_urn(urn, themes):
    return {x:nb.word_freq(urn, themes[x]) for x in themes}

# %%
check_urn(2008111304008, themes_plus)
# Out:
# {'dynen-hunger': {'armbåndsur': 1,
#   'askebeger': 1,
#   'dyna': 1,
#   'fersken': 1,
#   'munnviken': 1,
#   'rubin': 1,
#   'sitrende': 1,
#   'slappe': 1,
#   'slappes': 1,
#   'svimlende': 1,
#   'sitret': 2,
#   'slikket': 2,
#   'slapp': 3,
#   'slapper': 3,
#   'absolutt': 12},
#  'henrykt-sosialist': {'belest': 1,
#   'beleste': 1,
#   'fiolin': 1,
#   'fløyter': 1,
#   'forsmedelsen': 1,
#   'gymnasiaster': 1,
#   'henrykt': 1,
#   'henrykte': 1,
#   'hurtigrute': 1,
#   'jernbaneskinnen': 1,
#   'kafeer': 1,
#   'murrende': 1,
#   'pinnestol': 1,
#   'pinnestoler': 1,
#   'siderom': 1,
#   'siderommet': 1,
#   'skandinavene': 1,
#   'skandinaver': 1,
#   'hurtigruta': 3,
#   'kafé': 3,
#   'subb': 3,
#   'gymnasiast': 4,
#   'gymnasiasten': 4,
#   'sosialisten': 4,
#   'forelskelsen': 5,
#   'sosialist': 5,
#   'forelskelse': 10},
#  'svelger-blaff': {'armbåndsur': 1,
#   'blaffen': 1,
#   'bondegård': 1,
#   'brunst': 1,
#   'divan': 1,
#   'fornemmes': 1,
#   'forsonet': 1,
#   'gløttet': 1,
#   'skotte': 1,
#   'svelge': 1,
#   'svelger': 1,
#   'underarm': 1,
#   'underliv': 1,
#   'velde': 1,
#   'vellyst': 1,
#   'væte': 1,
#   'fornem': 2,
#   'fornemmet': 2,
#   'gløtt': 2,
#   'dulgt': 3,
#   'skotter': 3,
#   'fornemmer': 7,
#   'fornemme': 20},
#  'forelesningene-auditoriet': {'auditoriene': 1,
#   'kateteret': 1,
#   'klassekameratene': 1,
#   'lesesalen': 1,
#   'takrenne': 1,
#   'klassekamerat': 2,
#   'klassekameraten': 2,
#   'klassekamerater': 2,
#   'skjød': 2,
#   'øde': 2},
#  'studenten-andakt': {'barberkniven': 1,
#   'henrykt': 1,
#   'henrykte': 1,
#   'ranker': 1,
#   'studentene': 1,
#   'svevet': 1,
#   'vemod': 1,
#   'buksen': 2,
#   'buksene': 2,
#   'bukser': 2,
#   'studenten': 2,
#   'sveve': 2,
#   'nesebor': 4,
#   'studenter': 4,
#   'svever': 4,
#   'rank': 5,
#   'ranke': 5,
#   'student': 10},
#  'skjensel-minte': {'hytteturen': 1,
#   'høyskole': 1,
#   'kateteret': 1,
#   'kontrollør': 1,
#   'miner': 1,
#   'minnes': 1,
#   'sjøstøvler': 1,
#   'skrivemaskinene': 1,
#   'trikk': 1,
#   'avsky': 2,
#   'bestyrer': 2,
#   'gasje': 2,
#   'skrivemaskiner': 2,
#   'skrivemaskin': 3,
#   'skrivemaskinen': 5,
#   'trikken': 6,
#   'minnet': 23,
#   'mine': 24,
#   'minne': 25,
#   'minner': 29,
#   'min': 126},
#  'hybelen-hybel': {'bøyer': 1,
#   'dansemoro': 1,
#   'divan': 1,
#   'hals': 1,
#   'hedret': 1,
#   'hybelen': 1,
#   'knott': 1,
#   'knotten': 1,
#   'maven': 1,
#   'overleppene': 1,
#   'sitrende': 1,
#   'skotte': 1,
#   'snippen': 1,
#   'turnsko': 1,
#   'yttertøy': 1,
#   'mave': 2,
#   'sitret': 2,
#   'telegrammer': 2,
#   'bøyde': 3,
#   'hybel': 3,
#   'skotter': 3,
#   'snipp': 3},
#  'motorsykkel-pensjonatet': {'fløytende': 1,
#   'fløyter': 1,
#   'kubikk': 1,
#   'motorsykkelen': 1,
#   'pensjonatene': 1,
#   'pensjonater': 1,
#   'smilerynkene': 1,
#   'smilerynker': 1,
#   'musene': 2,
#   'motorsykkel': 3,
#   'pensjonatet': 6,
#   'pensjonat': 9},
#  'handelsskole-underarm': {'gammelost': 1, 'underarm': 1},
#  'øyenlokk-ryster': {'billedboka': 1,
#   'brekke': 1,
#   'gymnasiaster': 1,
#   'kinnben': 1,
#   'øyenlokkene': 1,
#   'putevaret': 2,
#   'rystende': 2,
#   'rystet': 2,
#   'gymnasiast': 4,
#   'gymnasiasten': 4,
#   'nattbordet': 4}}

# %%
values = [x for y in themes_plus.values() for x in y]

# %%
GL = nb.make_network_graph(2008111304008, values)

# %%
gnl.show_graph(GL)

# %%
gnl.show_communities(GL)
# Out:
# pensjonat-fornemme :  pensjonat, fornemme, absolutt, pensjonatet, knott, knotten, siderom, hybel
#
# student-auditoriene :  student, auditoriene, lesesalen
#
# gymnasiast-bukser :  gymnasiast, bukser, munnviken, beleste, minnes, kateteret
#
# kafé-hurtigruta :  kafé, hurtigruta, brekke
#
# klassekamerater-buksene :  klassekamerater, buksene, bøyer, klassekamerat
#
# min-minner :  min, minner, mine, skrivemaskin, skrivemaskinene, mave, subb, sitret, sjøstøvler, pinnestoler, klassekameratene, underliv, skrivemaskinen, hals
#
# gløttet-fløytende :  gløttet, fløytende
#
# forelskelse-trikk :  forelskelse, trikk, forelskelsen
#
# minne-minnet :  minne, minnet, slappe, skotter, fornemmer, forsmedelsen
#
# sveve-fornemmes :  sveve, fornemmes
#
# motorsykkel-trikken :  motorsykkel, trikken, kubikk
#
# nesebor-svever :  nesebor, svever
#
# snipp-rank :  snipp, rank, snippen
#
# ranke-skotte :  ranke, skotte, studenter
#
# skrivemaskiner-svimlende :  skrivemaskiner, svimlende
