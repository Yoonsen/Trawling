# %% [markdown]
# # TM
#
# Temamodellering basert på clustring, klikk og grafanalyse.
#
# Her ser vi på
# 1. Bygg et korpus
# 1. Hvordan hente ut tematiske strukturer fra korpus
# 1. Hvordan evaluere temaer mot et større korpus
#
# Om de tematisk strukturene kommer et annetsteds fra, så kan evalueringen fremdeles benyttes, og evalueres mot bokhyllas data.

# %% [markdown]
# ### først litt kode for å komme i gang

# %%
import json
import pandas as pd
import dhlab.module_update as mu
mu.update('mods_meta')
import mods_meta as mm
import dhlab.nbtext as nb
import re
from IPython.display import Markdown, display
from collections import Counter
from dhlab.nbtokenizer import tokenize
import networkx as nx
import dhlab.graph_networkx_louvain as gnl
import datetime
from scipy.spatial.distance import cosine
from sklearn.metrics.pairwise import cosine_similarity, cosine_distances
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import json
mu.update('wordbank')
# Out:
# Updated file `C:\Users\yoons\Documents\GitHub\Trawling\mods_meta.py`
# Updated file `C:\Users\yoons\Documents\GitHub\Trawling\wordbank.py`

# %%
from wordbank import word_paradigm_many, word_lemma_many, word_form_many

# %%
mu.css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# Set fontsizes for plots etc.

# %%
from nb_api_kollokasjon_konk import *
# Out:
# Updated file `C:\Users\yoons\Documents\GitHub\Trawling\mods_meta.py`
# Updated file `C:\Users\yoons\Documents\GitHub\Trawling\collocations.py`

# %%
def declensions(wordbagfamily, pos = None):
    """Set pos to subst, verb or adj for limiting the inflectional forms"""
    if isinstance(pos, list):
        res = {key: list(set([w for infl_set in word_para(wordbagfamily[key]) for w in infl_set[2] if infl_set [1] in pos])) for key in wordbagfamily}
    elif isinstance( pos, str):
        res = {key: list(set([w for infl_set in word_para(wordbagfamily[key]) for w in infl_set[2] if infl_set [1] == pos])) for key in wordbagfamily}
    else:
        res = {key: list(set([w for infl_set in word_para(wordbagfamily[key]) for w in infl_set[2]])) for key in wordbagfamily}
    return res

# %%
def word_para(ws):
    res = word_paradigm_many(ws)
    for w in ws:
        if w not in [x[0] for x in res]:
            res.append([w, 'subs', [w]])
    return res

# %%
word_para(['Arbeidere', 'idretten'])
# Out:
# [['idretten', 'subs', ['idrett', 'idretten', 'idrettene', 'idretter']],
#  ['Arbeidere', 'subs', ['Arbeidere']]]

# %% [markdown]
# # Analyse

# %% [markdown]
# ### Sammenligning
#
# Det kan være greit å ha en samling ord for utvalg av et sett ord fra korpuset. Om vi satser på en standard forskjellsanalyse, tar vi utgangspunkt i de 200 000 mest frekvente ordene i bokhylla. Tallet kan økes.

# %%
tot = nb.frame(nb.totals(200000), 'tot')

# %%
nb.normalize_corpus_dataframe(tot)
# Out:
# True

# %% [markdown]
# ### Korpus
#
# Bygg et korpus på en eller annen måte. Her ser vi på 10 bøker hentet fra en bestemt periode, markert med emneordet 'krig'.

# %%
books_ = nb.book_corpus(author = 'mykle%agnar%', lang= 'nob', period = (1940, 2010))

# %% [markdown]
# En kjapp oversikt over titler og forfatter.

# %%
books_
# Out:
#               urn        author                      title  year
# 0   2016020808126  Mykle, Agnar   Sangen om den røde rubin  2000
# 1   2014111108298  Mykle, Agnar       Lasso rundt fru Luna  2007
# 2   2008072504129  Mykle, Agnar           Samlede noveller  1996
# 3   2008021104057  Mykle, Agnar             Samlede verker  1994
# 4   2012020208192  Mykle, Agnar             Kors på halsen  1958
# 5   2008020701019  Mykle, Agnar             Samlede verker  1994
# 6   2014072108181  Mykle, Agnar       Lasso rundt fru Luna  2006
# 7   2008012100052  Mykle, Agnar             Samlede verker  1994
# 8   2007052404016  Mykle, Agnar   Sangen om den røde rubin  1967
# 9   2008072800017  Mykle, Agnar          mann og hans vask  1996
# 10  2009062400001  Mykle, Agnar       Lasso rundt fru Luna  1998
# 11  2008020504106  Mykle, Agnar             Samlede verker  1994
# 12  2011111608114  Mykle, Agnar  Tyven, tyven skal du hete  1951
# 13  2008021104029  Mykle, Agnar   Sangen om den røde rubin  1995
# 14  2009062900060  Mykle, Agnar                Noveller II  2000
# 15  2011070805071  Mykle, Agnar           Kjære lille Moff  2004
# 16  2014010308002  Mykle, Agnar      Morgen i appelsingult  1951
# 17  2008022200094  Mykle, Agnar  Tyven, tyven skal du hete  1995
# 18  2009012000014  Mykle, Agnar           v og annen prosa  1998
# 19  2009032304054  Mykle, Agnar                    Rubicon  1999

# %%
books = books_[books_.urn.isin([2016020808126,2009032304054,2009062400001])]

# %%
books
# Out:
#               urn        author                     title  year
# 0   2016020808126  Mykle, Agnar  Sangen om den røde rubin  2000
# 10  2009062400001  Mykle, Agnar      Lasso rundt fru Luna  1998
# 19  2009032304054  Mykle, Agnar                   Rubicon  1999

# %% [markdown]
# For å analysere samforekomster, telles ordene. Korpuset her tilsvarer subcorpus i Tangherlini&Leonard. Desto mindre jo bedre. Ordfrekvensene normaliseres i samme rennet.
#
# Her ser vi på trilogien Rubicon, Lass og Sangen

# %%
df = nb.frame(nb.aggregate_urns(list(books.urn)))
nb.normalize_corpus_dataframe(df)
# Out:
# True

# %% [markdown]
# Når ordene sammenlignes med det som er forventet dukker det opp en slags tematisk struktur, som vi ser i neste output. Ordene er toppordene for de som utgjør en forskjell på korpuset sammenlignet med resten av bokhylla. Men merk at enkelte bøker kan dominere her, så derfor lurt å minske antallet, eller analysere bøkene en for en.
#
# Vi bruker korpus-ordene for å lage en tematisk struktur. Alt vi vet foreløpig er at hver og en av dem forekommer hyppigere i korpuset enn ellers i bokverdenen. Hvordan henger de sammen?

# %%
list(nb.frame_sort(nb.frame(df[0]/tot.tot)).head(20).index)
# Out:
# ['Ask',
#  'Valemon',
#  'Doffen',
#  'Embla',
#  'Mhm',
#  'Barmhjertige',
#  'Efterpå',
#  'Stallen',
#  'Studentersamfunnet',
#  'Balder',
#  'skjensel',
#  'lommetørklæet',
#  'forjettende',
#  'hjelpelærer',
#  'efterpå',
#  'skjendig',
#  'bestyrerens',
#  'hissende',
#  'Lasso',
#  'bestyreren']

# %% [markdown]
# Ordene over kan vi bruke til å konstruere en graf basert på samforekomster. Kommandoen `nb.make_network_graph` tar en liste med ord og strukturer dem basert på samforekomst. Et ord W er koblet med en bue til et annet ord V, hvis W og V opptrer i samme avsnitt. Det gir en grafstruktur som kan visualiseres og analyseres.
#
# Her ser vi bare på ord som er mer eller mindre unike for tekstene i korpuset. Antallet ord bestemmes av parametret for `head()` i koden under. Her er den satt til 300, andre verdier gir flere ord, som vil øke størrels og antall på temaer.
#
# Ordene som skal brukes kunne i prinsippert vært hele korpuset, men for å komme i havn før nyttårsaften, og ikke sprenge datakapasiteten gjøres et utvalg. Forskjellig sett ord kan velges og gi andre resultat.

# %%
Gs = [nb.make_network_graph(str(u), list(nb.frame_sort(nb.frame(df[0]/tot.tot)).head(300).index)) for u in books.urn]

# %%
G = nx.Graph()
for g in Gs:
    G.add_edges_from(g.edges(data=True))

# %% [markdown]
# Grafen ser sånn ut. Med fargelagte noder for clustertilhørighet.

# %%
gnl.show_graph(G, spread = 1.5)

# %% [markdown]
# Nedenfor kan vi se på clustrene generert fra grafen (Louvain-metoden), som til syvende og sist er antatt å definere et aspekt ved den tematiske strukturen for korpuset. Tematikken er her basert på de viktigste ordene, beskrevet ovenfor. Andre detaljer vil komme frem ved å bruke andre ord som input, ordsekker laget ved kollokasjon for eksempel.
#
# En mulig svakhet ved clustringsalgoritmer er at de partisjonerer ordene, sånn at ord ikke forekommer i to eller fler clustre, til forskjell fra mixtur-modeller som LDA og NMF. Klikkstrukturene er bedre i så henseende. Vi bruker dem ikke nå i første omgang men se artikkelen om forskjellen på klikk og clustring ["Graph Analysis of Word Networks”](http://ceur-ws.org/Vol-2021/paper6.pdf)..
#
# Merkelappen på clustrene er hentet fra de mest sentrale ordene i clustret. Og hjelper litt med en begrepsmessig orden.

# %%
gnl.show_communities(G)
# Out:
# Ask-umåtelig :  Ask, umåtelig, Gunnhild, Efterpå, Doffen, Pelle, bestyreren, arrig, handelsskole, umåtelige, klædd, lystighet, Taraldsen, Bestyreren, hurtigruten, Rex, gymnasiet, begripelse, landgangen, snadde, Maia, armbåndsuret, bestyrerens, belesset, blyghet, Flose, køyen, uforløst, ridestøvler, meteorologene, lærerværelset, pikers, køye, sangkoret, lokalbåten, revnende, handelsfag, forvokst, bordduken, hjelpelærer, ranket, vestelommen, uskjønt, verdensrom, Heh, plirte, meteorolog, hakkende, handelsskolen, taps-, stortåen, Gullaksen, fortann, knickers, takrennen, Dunk, gammelost, krykken, Mhm, hårlokken, unnfly, fadese, Stoppet, jernbaneskinner, Mustapha, Merci, Albrechtsen, blåbærlyng, hurtigrute, drevende, grunnende, billettluken, siderommet, riflete
#
# Embla-treogtyve :  Embla, treogtyve, Barmhjertige, Stallen, unevnelig, druknende, gymnasier, stensilerte, smilerynker, nøttebrune, Hautes, Méd
#
# hastig-attpåtil :  hastig, attpåtil, Constance, studenten, dynen, svelger, hårdt, Studenten, skjendig, skotte, Valemon, stønnende, bortvendt, hikstende, nydelse, pikes, studentens, underliv, prikkende, bjerg, midje, lommetørklæet, skaker, skotter, svimlet, mykhet, overleppe, fnisende, dén, håndflate, silkestrømper, aristokrat, forkjølt, overmunnen, barbar, brystholderen, slappes, forhjulet, bortefter, rubin, veldet, plirende, uvasket, professorens, tolleren, ødet, forklæ, gulerøtter, tannlæge, ufint, vindusposten, hvithårete, konverserte, uvettige, langsefter, vårnatt, forsonte, rumpen, kvidder, barberkniv, gnikket, hårsbredd, glefsende, sprengende, Lasso, frakkelommen, Rubicon, bakhjulet, løftende, gysen, junidag, revoir, frykteligere, telefonboksen, fullbragt, Prosit, foresvevet, Hia, lydd, Wiedersehen
#
# dét-avsindig :  dét, avsindig, Balder, blaff, barmhjertige, divanen, fornemmet, sitrende, Dét, elve, håndtrykk, lommetørklæ, smukk, nachspiel, dansemoro, skolebestyrer, harske, taktstokken, middagslur, lasso, Uvet, festtaler, halvlyset, Hah, vranten, lassoen, Varsomt, brekket, grøssende, fløytet, Balders, harmonilære, Dostojevski, Seid, Hastig, Jawohl, vellysten
#
# sosialist-Stabell :  sosialist, Stabell, sosialister, dulgt, sosialistene, Studentersamfunnet, vanmakt, Kameraden, mimret, uselviskhet, skandinav, lettsinn
#
# efterpå-hybelen :  efterpå, hybelen, hybel, gyste, klæ, bøyet, Wilhelmine, hissende, brunst, mavesår, blomsterpotte, klædde, fiolinen, døddrukken, fyllepenn, hikster, kajakken, artiklen, krampegråt, sordin, fantasiløs, forsmedelse, tyttebærsyltetøy, murhus, grafset, vaskevannsfatet, smokingen, underkjeve, skjendet, eftertenksomt, samforstand, Trotsky, bukselomme, skipskaptein, knottene
#
# distré-auditoriet :  distré, auditoriet, katetret, frysende, sorgfullt, frikvarterene, skoleplassen, tommeltotten, frikvarteret, arrige, villende, skoleplass, svarthåret, hedrer, påjakt
#
# hastige-øyenlokk :  hastige, øyenlokk, fargetone, fiolblå, uberørt, ringeknappen
#
# skjensel-skjendige :  skjensel, skjendige, henrykte, sjanglende, forjettende, hånds, halset, underarmer, høk, ulidelige, hornbriller, tarveligste
#
# hyttetur-fenriken :  hyttetur, fenriken, åj
#
# armbåndsur-forsovet :  armbåndsur, forsovet, mennesketomme, fotsåler

# %% [markdown]
# ### Evaluering, tråling
#
# Temaene generert over kan analyseres på selve korpuset, eller på et annet større korpus. Først ser vi på selve korpust

# %% [markdown]
# Temaene hentes ut som en familie ordklasser

# %%
themes = gnl.community_dict(G)

# %% [markdown]
# For å få med bøyningsvarianter, legger vi til infleksjonsformer for ord som har det.

# %%
themes_plus = declensions(themes)

# %% [markdown]
# ### Gå gjennom bøker og tell opp temaene

# %%
evals = nb.wordbag_eval(themes_plus, list(books_.urn)).astype(int)

# %%
evals.style.background_gradient(axis = 0)
# Out:
# <style  type="text/css" >
#     #T_7a69a464_2920_11eb_89c4_985fd3509bc7row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row0_col1 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row0_col2 {
#             background-color:  #045280;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row0_col7 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row0_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row0_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row0_col10 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row0_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row1_col0 {
#             background-color:  #045687;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row1_col1 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row1_col2 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row1_col3 {
#             background-color:  #046097;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row1_col4 {
#             background-color:  #034c78;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row1_col5 {
#             background-color:  #046097;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row1_col6 {
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row1_col7 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row1_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row1_col9 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row1_col10 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row1_col11 {
#             background-color:  #045a8d;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row2_col0 {
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row2_col1 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row2_col2 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row2_col3 {
#             background-color:  #046198;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row2_col4 {
#             background-color:  #045b8e;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row2_col5 {
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row2_col6 {
#             background-color:  #046097;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row2_col7 {
#             background-color:  #4a98c5;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row2_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row2_col9 {
#             background-color:  #04649d;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row2_col10 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row2_col11 {
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row3_col0 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row3_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row3_col3 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row3_col4 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row3_col5 {
#             background-color:  #03466e;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row3_col6 {
#             background-color:  #034c78;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row3_col7 {
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row3_col8 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row3_col9 {
#             background-color:  #a1bbda;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row3_col10 {
#             background-color:  #02395a;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row3_col11 {
#             background-color:  #4897c4;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row4_col0 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row4_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row4_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row4_col3 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row4_col4 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row4_col5 {
#             background-color:  #03466e;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row4_col6 {
#             background-color:  #034d79;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row4_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row4_col8 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row4_col9 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row4_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7a69a464_2920_11eb_89c4_985fd3509bc7row4_col11 {
#             background-color:  #4897c4;
#             color:  #0

# %% [markdown]
# ### Evaluere mot et skjønnlitterært korpus fra samme era.
#
# Evalueringen er uavhengig av hvordan temaordene er laget. De kan lages for hånd, genereres med LDA, eller som over, hentet fra grafer. Evalueringen teller opp ordsekkfamilien over et sett ord.

# %%
testkorpus = nb.book_corpus(ddk = '839%', period = (1990, 2010), limit = 20)

# %%
testeval = nb.wordbag_eval(themes_plus, list(testkorpus.urn)).astype(int)

# %% [markdown]
# Korpuset er litt for stort til visualisering, så sorterer på et trekk og tar ut de 50 beste

# %%
testeval.sort_values(by = 'snitt', ascending = False).head(50).style.background_gradient(axis = 0)
# Out:
# <style  type="text/css" >
#     #T_03041428_2921_11eb_bc5e_985fd3509bc7row0_col0 {
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row0_col1 {
#             background-color:  #358fc0;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row0_col3 {
#             background-color:  #03517e;
#             color:  #f1f1f1;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row0_col7 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row0_col8 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row0_col9 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row0_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row1_col0 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row1_col1 {
#             background-color:  #358fc0;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row1_col2 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row1_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row1_col4 {
#             background-color:  #056aa6;
#             color:  #f1f1f1;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row1_col5 {
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row1_col6 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row1_col7 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row1_col8 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row1_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row1_col10 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row2_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row2_col2 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row2_col3 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row2_col4 {
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row2_col5 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row2_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row2_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row2_col8 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row2_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row2_col10 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row3_col0 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row3_col1 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row3_col2 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row3_col3 {
#             background-color:  #2081b9;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row3_col4 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row3_col5 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row3_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row3_col7 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row3_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row3_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row3_col10 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row4_col0 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row4_col1 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row4_col2 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row4_col3 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row4_col4 {
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row4_col5 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row4_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row4_col7 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row4_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row4_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row4_col10 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row5_col0 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row5_col1 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row5_col2 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row5_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_03041428_2921_11eb_bc5e_985fd3509bc7row5_col4 {
#             background-color:  #e1dfed;
#             color:  #000000

# %%
mdata = [nb.metadata(u) for u in testeval.sort_values(by = 'snitt', ascending = False).head(50).index]

# %%
nb.frame(mdata)
# Out:
#                                                     0
# 0   [2008080800070, Lagerlöf, Selma, 1996, Jerusal...
# 1   [2016010807517, Tvedt, Chris, 2010, Rottejeger...
# 2   [2008033104018, Jensen, Axel, 1995, Og resten ...
# 3   [2010102920011, Osmundsen, Mari, 1990, Wow, sj...
# 4   [2014070108089, Hagerup, Hilde, 2007, Løvetann...
# 5   [2008022001016, , 1995, Karneval, ungdomsnovel...
# 6   [2015011608159, Johansen, Dag Ove, 2002, Vindm...
# 7   [2008022104001, Hagen, Oddmund, 1995, Denne br...
# 8   [2014071808063, Opås, Rolf, 1994, Samlede nove...
# 9   [2014102724005, , 2007, Nordlys nordisk, norsk...
# 10  [2009012904104, Nilsen, Svein Roger, 1997, Hve...
# 11  [2008081400071, Nilsson, Ulf, 1998, Det egypti...
# 12  [2012072509118, Fosse, Jon, 2000, Natta syng s...
# 13  [2008080700088, Peterson, Hans, 1998, Au, det ...
# 14  [2008070700059, Sæter, Alf A., 1996, På begge ...
